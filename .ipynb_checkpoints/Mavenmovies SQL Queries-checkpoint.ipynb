# %%
# import libraries
import pandas as pd

# %%
# install the ipython-sql library
# !pip install ipython-sql
# !pip3 install mysqlclient
# Out:
# Requirement already satisfied: ipython-sql in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (3.7.0)
# Requirement already satisfied: ipython in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (8.12.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (2.0.11)
# Requirement already satisfied: sqlparse in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.2)
# Requirement already satisfied: backcall in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: colorama in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: mysqlclient in c:\users\sanjay\appdata\local\programs\python\python311\lib\site-packages (2.1.1)

# %%
# load the SQL modules
# %load_ext sql

# %% [markdown]
# # Answer the following questions using the database

# %% [markdown]
# ## 1. Write a SQL query to count the number of characters except the spaces for each actor. Return first 10 actors name length along with their name.

# %%
# %%sql
# select concat(first_name," ",last_name)as Actor_Name,length(concat(first_name,"",last_name)) as Name_Length
# from actor limit 10;
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 10 rows affected.
# [('PENELOPE GUINESS', 15),
#  ('NICK WAHLBERG', 12),
#  ('ED CHASE', 7),
#  ('JENNIFER DAVIS', 13),
#  ('JOHNNY LOLLOBRIGIDA', 18),
#  ('BETTE NICHOLSON', 14),
#  ('GRACE MOSTEL', 11),
#  ('MATTHEW JOHANSSON', 16),
#  ('JOE SWANK', 8),
#  ('CHRISTIAN GABLE', 14)]

# %% [markdown]
# ## 2. List all Oscar awardees(Actors who received Oscar award) with their full names and length of their names.

# %%
# %%sql
# select actor_id as ID,concat(first_name," ",last_name) as Full_Name,length(concat(first_name," ",last_name)) as Name_Length,awards as Award
# from actor_award
# where awards like '%oscar%';
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 89 rows affected.
# [(12, 'KARL BERRY', 10, 'Emmy, Oscar, Tony '),
#  (21, 'KIRSTEN PALTROW', 15, 'Emmy, Oscar, Tony '),
#  (51, 'GARY PHOENIX', 12, 'Emmy, Oscar, Tony '),
#  (123, 'JULIANNE DENCH', 14, 'Emmy, Oscar, Tony '),
#  (None, 'RODNEY MINERSON', 15, 'Emmy, Oscar, Tony '),
#  (None, 'BLAKE SIMON', 11, 'Emmy, Oscar, Tony '),
#  (None, 'KATIE SUGARPLUM', 15, 'Emmy, Oscar, Tony '),
#  (1, 'PENELOPE GUINESS', 16, 'Emmy, Oscar'),
#  (18, 'DAN TORN', 8, 'Emmy, Oscar'),
#  (27, 'JULIA MCQUEEN', 13, 'Emmy, Oscar'),
#  (35, 'JUDY DEAN', 9, 'Emmy, Oscar'),
#  (37, 'VAL BOLGER', 10, 'Emmy, Oscar'),
#  (52, 'CARMEN HUNT', 11, 'Emmy, Oscar'),
#  (57, 'JUDE CRUISE', 11, 'Emmy, Oscar'),
#  (65, 'ANGELA HUDSON', 13, 'Emmy, Oscar'),
#  (70, 'MICHELLE MCCONAUGHEY', 20, 'Emmy, Oscar'),
#  (72, 'SEAN WILLIAMS', 13, 'Emmy, Oscar'),
#  (75, 'BURT POSEY', 10, 'Emmy, Oscar'),
#  (83, 'BEN WILLIS', 10, 'Emmy, Oscar'),
#  (98, 'CHRIS BRIDGES', 13, 'Emmy, Oscar'),
#  (102, 'WALTER TORN', 11, 'Emmy, Oscar'),
#  (109, 'SYLVESTER DERN', 14, 'Emmy, Oscar'),
#  (110, 'SUSAN DAVIS', 11, 'Emmy, Oscar'),
#  (111, 'CAMERON ZELLWEGER', 17, 'Emmy, Oscar'),
#  (116, 'DAN STREEP', 10, 'Emmy, Oscar'),
#  (117, 'RENEE TRACY', 11, 'Emmy, Oscar'),
#  (119, 'WARREN JACKMAN', 14, 'Emmy, Oscar'),
#  (129, 'DARYL CRAWFORD', 14, 'Emmy, Oscar'),
#  (145, 'KIM ALLEN', 9, 'Emmy, Oscar'),
#  (172, 'GROUCHO WILLIAMS', 16, 'Emmy, Oscar'),
#  (174, 'MICHAEL BENING', 14, 'Emmy, Oscar'),
#  (185, 'MICHAEL BOLGER', 14, 'Emmy, Oscar'),
#  (186, 'JULIA ZELLWEGER', 15, 'Emmy, Oscar'),
#  (None, 'SPIKE THOMPSON', 14, 'Emmy, Oscar'),
#  (None, 'ADAM HOLMVICK', 13, 'Emmy, Oscar'),
#  (19, 'BOB FAWCETT', 11, 'Oscar, Tony'),
#  (28, 'WOODY HOFFMAN', 13, 'Oscar, Tony'),
#  (48, 'FRANCES DAY-LEWIS', 17, 'Oscar, Tony'),
#  (49, 'ANNE CRONYN', 11, 'Oscar, Tony'),
#  (58, 'CHRISTIAN AKROYD', 16, 'Oscar, Tony'),
#  (66, 'MARY TANDY', 10, 'Oscar, Tony'),
#  (68, 'RIP WINSLET', 11, 'Oscar, Tony'),
#  (69, 'KENNETH PALTROW', 15, 'Oscar, Tony'),
#  (71, 'ADAM GRANT', 10, 'Oscar, Tony'),
#  (74, 'MILLA KEITEL', 12, 'Oscar, Tony'),
#  (78, 'GROUCHO SINATRA', 15, 'Oscar, Tony'),
#  (112, 'RUSSELL BACALL', 14, 'Oscar, Tony'),
#  (154, 'MERYL GIBSON', 12, 'Oscar, Tony'),
#  (159, 'LAURA BRODY', 11, 'Oscar, Tony'),
#  (162, 'OPRAH KILMER', 12, 'Oscar, Tony'),
#  (165, 'AL GARLAND', 10, 'Oscar, Tony'),
#  (173, 'ALAN DREYFUSS', 13, 'Oscar, Tony'),
#  (175, 'WILLIAM HACKMAN', 15, 'Oscar, Tony'),
#  (180, 'JEFF SILVERSTONE', 16, 'Oscar, Tony'),
#  (182, 'DEBBIE AKROYD', 13, 'Oscar, Tony'),
#  (187, 'RENEE BALL', 10, 'Oscar, Tony'),
#  (193, 'BURT TEMPLE', 11, 'Oscar, Tony'),
#  (200, 'THORA TEMPLE', 12, 'Oscar, Tony'),
#  (6, 'BETTE NICHOLSON', 15, 'Oscar'),
#  (9, 'JOE SWANK', 9, 'Oscar'),
#  (29, 'ALEC WAYNE', 10, 'Oscar'),
#  (32, 'TIM HACKMAN', 11, 'Oscar'),
#  (36, 'BURT DUKAKIS', 12, 'Oscar'),
#  (38, 'TOM MCKELLEN', 12, 'Oscar'),
#  (76, 'ANGELINA ASTAIRE', 16, 'Oscar'),
#  (84, 'JAMES PITT', 10, 'Oscar'),
#  (85, 'MINNIE ZELLWEGER', 16, 'Oscar'),
#  (99, 'JIM MOSTEL', 10, 'Oscar'),
#  (101, 'SUSAN DAVIS', 11, 'Oscar'),
#  (120, 'PENELOPE MONROE', 15, 'Oscar'),
#  (125, 'ALBERT NOLTE', 12, 'Oscar'),
#  (131, 'JANE JACKMAN', 12, 'Oscar'),
#  (133, 'RICHARD PENN', 12, 'Oscar'),
#  (143, 'RIVER DEAN', 10, 'Oscar'),
#  (148, 'EMILY DEE', 9, 'Oscar'),
#  (150, 'JAYNE NOLTE', 11, 'Oscar'),
#  (152, 'BEN HARRIS', 10, 'Oscar'),
#  (153, 'MINNIE KILMER', 13, 'Oscar'),
#  (156, 'FAY WOOD', 8, 'Oscar'),
#  (161, 'HARVEY HOPE', 11, 'Oscar'),
#  (163, 'CHRISTOPHER WEST', 16, 'Oscar'),
#  (164, 'HUMPHREY WILLIS', 15, 'Oscar'),
#  (167, 'LAURENCE BULLOCK', 16, 'Oscar'),
#  (178, 'LISA MONROE', 11, 'Oscar'),
#  (181, 'MATTHEW CARREY', 14, 'Oscar'),
#  (183, 'RUSSELL CLOSE', 13, 'Oscar'),
#  (None, 'LARRY SYKES', 11, 'Oscar'),
#  (None, 'GOOCH MCDANGER', 14, 'Oscar'),
#  (None, 'MONTY WINTER', 12, 'Oscar')]

# %% [markdown]
# ## 3. Find the actors who have acted in the film ‘Frost Head’.

# %%
# %%sql
# select a.actor_id as Actor_ID,concat(a.first_name," ",a.last_name) as Actors_name
# from actor a
# inner join film_actor fa
# on fa.actor_id=a.actor_id
# inner join film f
# on f.film_id=fa.film_id
# where f.title='Frost Head';
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 7 rows affected.
# [(3, 'ED CHASE'),
#  (52, 'CARMEN HUNT'),
#  (80, 'RALPH CRUZ'),
#  (134, 'GENE HOPKINS'),
#  (141, 'CATE HARRIS'),
#  (147, 'FAY WINSLET'),
#  (167, 'LAURENCE BULLOCK')]

# %% [markdown]
# ## 4. Pull all the films acted by the actor ‘Will Wilson’.

# %%
# %%sql
# select f.film_id as Film_ID,f.title as Film_Name,concat(a.first_name," ",last_name) as Actor_Name
# from film f
# inner join film_actor fa
# on fa.film_id=f.film_id
# inner join actor a
# on a.actor_id=fa.actor_id
# where concat(first_name," ",last_name)='Will Wilson';
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 31 rows affected.
# [(32, 'APOCALYPSE FLAMINGOS', 'WILL WILSON'),
#  (56, 'BAREFOOT MANCHURIAN', 'WILL WILSON'),
#  (92, 'BOWFINGER GABLES', 'WILL WILSON'),
#  (115, 'CAMPUS REMEMBER', 'WILL WILSON'),
#  (188, 'CRAZY HOME', 'WILL WILSON'),
#  (196, 'CRUELTY UNFORGIVEN', 'WILL WILSON'),
#  (208, 'DARES PLUTO', 'WILL WILSON'),
#  (237, 'DIVORCE SHINING', 'WILL WILSON'),
#  (241, 'DONNIE ALLEY', 'WILL WILSON'),
#  (255, 'DRIVING POLISH', 'WILL WILSON'),
#  (305, 'FATAL HAUNTED', 'WILL WILSON'),
#  (336, 'FRENCH HOLIDAY', 'WILL WILSON'),
#  (387, 'GUN BONNIE', 'WILL WILSON'),
#  (433, 'HORN WORKING', 'WILL WILSON'),
#  (438, 'HUMAN GRAFFITI', 'WILL WILSON'),
#  (519, 'LIBERTY MAGNIFICENT', 'WILL WILSON'),
#  (602, 'MOURNING PURPLE', 'WILL WILSON'),
#  (619, 'NEIGHBORS CHARADE', 'WILL WILSON'),
#  (626, 'NOON PAPI', 'WILL WILSON'),
#  (652, 'PAJAMA JAWBREAKER', 'WILL WILSON'),
#  (678, 'PICKUP DRIVING', 'WILL WILSON'),
#  (685, 'PLATOON INSTINCT', 'WILL WILSON'),
#  (804, 'SLEEPING SUSPECTS', 'WILL WILSON'),
#  (807, 'SLEUTH ORIENT', 'WILL WILSON'),
#  (826, 'SPEED SUIT', 'WILL WILSON'),
#  (841, 'STAR OPERATION', 'WILL WILSON'),
#  (886, 'THEORY MERMAID', 'WILL WILSON'),
#  (889, 'TIES HUNGER', 'WILL WILSON'),
#  (892, 'TITANIC BOONDOCK', 'WILL WILSON'),
#  (927, 'UPRISING UPTOWN', 'WILL WILSON'),
#  (959, 'WARLOCK WEREWOLF', 'WILL WILSON')]

# %% [markdown]
# ## 5. Pull all the films which were rented and return in the month of May.

# %%
# %%sql
# select f.film_id as Film_ID,f.title as Film_Title,r.rental_date as Rental_Date,r.return_date as Return_date
# from film f
# left join inventory i
# on i.film_id=f.film_id
# left join rental r
# on r.inventory_id=i.inventory_id
# where r.return_date>='2005-05-01' and r.rental_date and r.return_date <'2005-06-01';
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 395 rows affected.
# [(80, 'BLANKET BEVERLY', datetime.datetime(2005, 5, 24, 22, 53, 30), datetime.datetime(2005, 5, 26, 22, 4, 30)),
#  (333, 'FREAKY POCUS', datetime.datetime(2005, 5, 24, 22, 54, 33), datetime.datetime(2005, 5, 28, 19, 40, 33)),
#  (613, 'MYSTIC TRUMAN', datetime.datetime(2005, 5, 24, 23, 8, 7), datetime.datetime(2005, 5, 27, 1, 32, 7)),
#  (870, 'SWARM GOLD', datetime.datetime(2005, 5, 24, 23, 11, 53), datetime.datetime(2005, 5, 29, 20, 34, 53)),
#  (510, 'LAWLESS VISION', datetime.datetime(2005, 5, 24, 23, 31, 46), datetime.datetime(2005, 5, 27, 23, 33, 46)),
#  (565, 'MATRIX SNOWMAN', datetime.datetime(2005, 5, 25, 0, 0, 40), datetime.datetime(2005, 5, 28, 0, 22, 40)),
#  (396, 'HANGING DEEP', datetime.datetime(2005, 5, 25, 0, 2, 21), datetime.datetime(2005, 5, 31, 22, 44, 21)),
#  (347, 'GAMES BOWFINGER', datetime.datetime(2005, 5, 25, 0, 19, 27), datetime.datetime(2005, 5, 30, 5, 44, 27)),
#  (499, 'KING EVOLUTION', datetime.datetime(2005, 5, 25, 0, 22, 55), datetime.datetime(2005, 5, 30, 4, 28, 55)),
#  (593, 'MONTEREY LABYRINTH', datetime.datetime(2005, 5, 25, 0, 31, 15), datetime.datetime(2005, 5, 26, 2, 56, 15)),
#  (86, 'BOOGIE AMELIE', datetime.datetime(2005, 5, 25, 0, 43, 11), datetime.datetime(2005, 5, 26, 4, 42, 11)),
#  (181, 'CONTACT ANONYMOUS', datetime.datetime(2005, 5, 25, 1, 6, 36), datetime.datetime(2005, 5, 27, 0, 43, 36)),
#  (741, 'ROMAN PUNK', datetime.datetime(2005, 5, 25, 1, 10, 47), datetime.datetime(2005, 5, 31, 6, 35, 47)),
#  (422, 'HOLLOW JEOPARDY', datetime.datetime(2005, 5, 25, 1, 17, 24), datetime.datetime(2005, 5, 31, 6, 0, 24)),
#  (770, 'SCISSORHANDS SLUMS', datetime.datetime(2005, 5, 25, 1, 48, 41), datetime.datetime(2005, 5, 27, 2, 20, 41)),
#  (31, 'APACHE DIVINE', datetime.datetime(2005, 5, 25, 1, 59, 46), datetime.datetime(2005, 5, 26, 1, 1, 46)),
#  (159, 'CLOSER BANG', datetime.datetime(2005, 5, 25, 2, 19, 23), datetime.datetime(2005, 5, 26, 4, 52, 23)),
#  (971, 'WHALE BIKINI', datetime.datetime(2005, 5, 25, 2, 40, 21), datetime.datetime(2005, 5, 29, 6, 34, 21)),
#  (721, 'REDS POCUS', datetime.datetime(2005, 5, 25, 2, 53, 2), datetime.datetime(2005, 5, 27, 1, 15, 2)),
#  (863, 'SUN CONFESSIONS', datetime.datetime(2005, 5, 25, 3, 21, 20), datetime.datetime(2005, 5, 27, 21, 25, 20)),
#  (953, 'WAIT CIDER', datetime.datetime(2005, 5, 25, 3, 36, 50), datetime.datetime(2005, 5, 31, 0, 34, 50)),
#  (271, 'EASY GLADIATOR', datetime.datetime(2005, 5, 25, 3, 41, 50), datetime.datetime(2005, 5, 30, 1, 13, 50)),
#  (887, 'THIEF PELICAN', datetime.datetime(2005, 5, 25, 3, 42, 37), datetime.datetime(2005, 5, 26, 9, 26, 37)),
#  (132, 'CHAINSAW UPTOWN', datetime.datetime(2005, 5, 25, 3, 47, 12), datetime.datetime(2005, 5, 30, 0, 31, 12)),
#  (819, 'SONG HEDWIG', datetime.datetime(2005, 5, 25, 4, 1, 32), datetime.datetime(2005, 5, 30, 3, 12, 32)),
#  (979, 'WITCHES PANIC', datetime.datetime(2005, 5, 25, 4, 5, 17), datetime.datetime(2005, 5, 30, 7, 15, 17)),
#  (839, 'STALLION SUNDANCE', datetime.datetime(2005, 5, 25, 4, 6, 21), datetime.datetime(2005, 5, 25, 23, 55, 21)),
#  (367, 'GOLDMINE TYCOON', datetime.datetime(2005, 5, 25, 4, 18, 51), datetime.datetime(2005, 5, 27, 3, 58, 51)),
#  (573, 'MICROCOSMOS PARADISE', datetime.datetime(2005, 5, 25, 4, 19, 28), datetime.datetime(2005, 5, 29, 0, 10, 28)),
#  (284, 'ENEMY ODDS', datetime.datetime(2005, 5, 25, 4, 24, 36), datetime.datetime(2005, 5, 27, 7, 2, 36)),
#  (288, 'ESCAPE METROPOLIS', datetime.datetime(2005, 5, 25, 4, 36, 26), datetime.datetime(2005, 5, 29, 0, 31, 26)),
#  (89, 'BORROWERS BEDAZZLED', datetime.datetime(2005, 5, 25, 4, 44, 31), datetime.datetime(2005, 5, 29, 1, 3, 31)),
#  (976, 'WIND PHANTOM', datetime.datetime(2005, 5, 25, 4, 51, 46), datetime.datetime(2005, 5, 31, 3, 14, 46)),
#  (579, 'MINDS TRUMAN', datetime.datetime(2005, 5, 25, 5, 9, 4), datetime.datetime(2005, 5, 27, 23, 12, 4)),
#  (84, 'BOILED DARES', datetime.datetime(2005, 5, 25, 5, 24, 58), datetime.datetime(2005, 5, 31, 2, 47, 58)),
#  (564, 'MASSAGE IMAGE', datetime.datetime(2005, 5, 25, 5, 39, 25), datetime.datetime(2005, 5, 26, 6, 54, 25)),
#  (681, 'PIRATES ROXANNE', datetime.datetime(2005, 5, 25, 5, 53, 23), datetime.datetime(2005, 5, 29, 10, 56, 23)),
#  (478, 'JAWS HARRY', datetime.datetime(2005, 5, 25, 6, 5, 20), datetime.datetime(2005, 5, 30, 3, 4, 20)),
#  (650, 'PACIFIC AMISTAD', datetime.datetime(2005, 5, 25, 6, 39, 35), datetime.datetime(2005, 5, 30, 10, 12, 35)),
#  (432, 'HOPE TOOTSIE', datetime.datetime(2005, 5, 25, 6, 44, 53), datetime.datetime(2005, 5, 28, 11, 28, 53)),
#  (278, 'ELF MURDER', datetime.datetime(2005, 5, 25, 6, 49, 10), datetime.datetime(2005, 5, 26, 6, 42, 10)),
#  (875, 'TALENTED HOMICIDE', datetime.datetime(2005, 5, 25, 6, 51, 29), datetime.datetime(2005, 5, 31, 1, 27, 29)),
#  (277, 'ELEPHANT TROJAN', datetime.datetime(2005, 5, 25, 7, 19, 16), datetime.datetime(2005, 5, 27, 5, 19, 16)),
#  (252, 'DREAM PICKUP', datetime.datetime(2005, 5, 25, 8, 26, 13), datetime.datetime(2005, 5, 30, 10, 57, 13)),
#  (298, 'EYES DRIVING', datetime.datetime(2005, 5, 25, 8, 28, 11), datetime.datetime(2005, 5, 26, 14, 21, 11)),
#  (858, 'SUBMARINE BED', datetime.datetime(2005, 5, 25, 8, 43, 32), datetime.datetime(2005, 5, 29, 6, 42, 32)),
#  (670, 'PELICAN COMFORTS', datetime.datetime(2005, 5, 25, 8, 53, 14), datetime.datetime(2005, 5, 28, 14, 40, 14)),
#  (73, 'BINGO TALENTED', datetime.datetime(2005, 5, 25, 8, 58, 25), datetime.datetime(2005, 5, 30, 14, 14, 25)),
#  (58, 'BEACH HEARTBREAKERS', datetime.datetime(2005, 5, 25, 9, 18, 52), datetime.datetime(2005, 5, 30, 10, 55, 52)),
#  (873, 'SWEETHEARTS SUSPECTS', datetime.datetime(2005, 5, 25, 9, 19, 16), datetime.datetime(2005, 5, 27, 4, 24, 16)),
#  (776, 'SECRET GROUNDHOG', datetime.datetime(2005, 5, 25, 9, 32, 3), datetime.datetime(2005, 5, 29, 14, 21, 3)),
#  (257, 'DRUMLINE CYCLONE', datetime.datetime(2005, 5, 25, 9, 35, 12), datetime.datetime(2005, 5, 29, 4, 16, 12)),
#  (54, 'BANGER PINOCCHIO', datetime.datetime(2005, 5, 25, 9, 41, 1), datetime.datetime(2005, 5, 27, 13, 46, 1)),
#  (878, 'TEEN APOLLO', datetime.datetime(2005, 5, 25, 9, 47, 31), datetime.datetime(2005, 5, 31, 10, 20, 31)),
#  (705, 'PURPLE MOVIE', datetime.datetime(2005, 5, 25, 10, 10, 14), datetime.datetime(2005, 5, 27, 14, 2, 14)),
#  (468, 'INVASION CYCLONE', datetime.datetime(2005, 5, 25, 10, 15, 23), datetime.datetime(2005, 5, 27, 5, 56, 23)),
#  (525, 'LOATHING LEGALLY', datetime.datetime(2005, 5, 25, 10, 26, 39), datetime.datetime(2005, 5, 28, 4, 59, 39)),
#  (489, 'JUGGLER HARDLY', datetime.datetime(2005, 5, 25, 10, 52, 13), datetime.datetime(2005, 5, 28, 5, 52, 13)),
#  (379, 'GREEDY ROOTS', datetime.datetime(2005, 5, 25, 11, 9, 48), datetime.datetime(2005, 5, 26, 12, 23, 48)),
#  (287, 'ENTRAPMENT SATISFACTION', datetime.datetime(2005, 5, 25, 11, 31, 59), datetime.datetime(2005, 5, 26, 16, 53, 59)),
#  (887, 'THIEF PELICAN', datetime.datetime(2005, 5, 25, 11, 35, 18), datetime.datetime(2005, 5, 31, 12, 48, 18)),
#  (543, 'MADIGAN DORADO', datetime.datetime(2005, 5, 25, 12, 12, 7), datetime.datetime(2005, 5, 31, 17, 46, 7)),
#  (103, 'BUCKET BROTHERHOOD', datetime.datetime(2005, 5, 25, 12, 30, 15), datetime.datetime(2005, 5, 27, 15, 40, 15)),
#  (397, 'HANKY OCTOBER', datetime.datetime(2005, 5, 25, 12, 36, 30), datetime.datetime(2005, 5, 29, 18, 33, 30)),
#  (103, 'BUCKET BROTHERHOOD', datetime.datetime(2005, 5, 25, 13, 5, 34), datetime.datetime(2005, 5, 29, 16, 53, 34)),
#  (491, 'JUMPING WRATH', datetime.datetime(2005, 5, 25, 13, 36, 12), datetime.datetime(2005, 5, 30, 14, 53, 12)),
#  (348, 'GANDHI KWAI', datetime.datetime(2005, 5, 25, 13, 52, 43), datetime.datetime(2005, 5, 29, 11, 12, 43)),
#  (480, 'JEEPERS WEDDING', datetime.datetime(2005, 5, 25, 14, 13, 54), datetime.datetime(2005, 5, 29, 9, 32, 54)),
#  (471, 'ISLAND EXORCIST', datetime.datetime(2005, 5, 25, 14, 28, 29), datetime.datetime(2005, 5, 29, 14, 33, 29)),
#  (169, 'COMFORTS RUSH', datetime.datetime(2005, 5, 25, 15, 38, 46), datetime.datetime(2005, 5, 31, 13, 40, 46)),
#  (366, 'GOLDFINGER SENSIBILITY', datetime.datetime(2005, 5, 25, 16, 3, 42), datetime.datetime(2005, 5, 30, 14, 23, 42)),
#  (748, 'RUGRATS SHAKESPEARE', datetime.datetime(2005, 5, 25, 16, 32, 19), datetime.datetime(2005, 5, 30, 10, 47, 19)),
#  (284, 'ENEMY ODDS', datetime.datetime(2005, 5, 25, 16, 34, 24), datetime.datetime(2005, 5, 28, 12, 13, 24)),
#  (651, 'PACKER MADIGAN', datetime.datetime(2005, 5, 25, 16, 48, 24), datetime.datetime(2005, 5, 27, 11, 29, 24)),
#  (117, 'CANDLES GRAPES', datetime.datetime(2005, 5, 25, 16, 50, 20), datetime.datetime(2005, 5, 28, 18, 52, 20)),
#  (134, 'CHAMPION FLATLINERS', datetime.datetime(2005, 5, 25, 17, 17, 4), datetime.datetime(2005, 5, 31, 19, 47, 4)),
#  (82, 'BLOOD ARGONAUTS', datetime.datetime(2005, 5, 25, 17, 22, 10), datetime.datetime(2005, 5, 31, 19, 47, 10)),
#  (932, 'VALLEY PACKER', datetime.datetime(2005, 5, 25, 17, 46, 33), datetime.datetime(2005, 5, 27, 15, 20, 33)),
#  (173, 'CONFESSIONS MAGUIRE', datetime.datetime(2005, 5, 25, 17, 54, 12), datetime.datetime(2005, 5, 30, 12, 3, 12)),
#  (724, 'REMEMBER DIARY', datetime.datetime(2005, 5, 25, 18, 30, 5), datetime.datetime(2005, 5, 30, 19, 40, 5)),
#  (233, 'DISCIPLE MOTHER', datetime.datetime(2005, 5, 25, 18, 40, 20), datetime.datetime(2005, 5, 29, 20, 39, 20)),
#  (814, 'SNATCH SLIPPER', datetime.datetime(2005, 5, 25, 18, 45, 19), datetime.datetime(2005, 5, 28, 17, 18, 19)),
#  (649, 'OZ LIAISONS', datetime.datetime(2005, 5, 25, 19, 7, 40), datetime.datetime(2005, 5, 27, 22, 16, 40)),
#  (164, 'COAST RAINBOW', datetime.datetime(2005, 5, 25, 19, 13, 25), datetime.datetime(2005, 5, 29, 20, 17, 25)),
#  (973, 'WIFE TURN', datetime.datetime(2005, 5, 25, 19, 27, 51), datetime.datetime(2005, 5, 26, 16, 23, 51)),
#  (931, 'VALENTINE VANISHING', datetime.datetime(2005, 5, 25, 19, 30, 46), datetime.datetime(2005, 5, 31, 23, 59, 46)),
#  (191, 'CROOKED FROGMEN', datetime.datetime(2005, 5, 25, 19, 31, 18), datetime.datetime(2005, 5, 31, 15, 0, 18)),
#  (300, 'FALCON VOLUME', datetime.datetime(2005, 5, 25, 19, 37, 2), datetime.datetime(2005, 5, 29, 23, 51, 2)),
#  (234, 'DISTURBING SCARFACE', datetime.datetime(2005, 5, 25, 19, 41, 29), datetime.datetime(2005, 5, 29, 21, 31, 29)),
#  (390, 'GUYS FALCON', datetime.datetime(2005, 5, 25, 20, 26, 42), datetime.datetime(2005, 5, 26, 19, 41, 42)),
#  (48, 'BACKLASH UNDEFEATED', datetime.datetime(2005, 5, 25, 20, 46, 11), datetime.datetime(2005, 5, 30, 0, 47, 11)),
#  (445, 'HYDE DOCTOR', datetime.datetime(2005, 5, 25, 21, 7, 59), datetime.datetime(2005, 5, 28, 18, 51, 59)),
#  (941, 'VIDEOTAPE ARSENIC', datetime.datetime(2005, 5, 25, 21, 19, 53), datetime.datetime(2005, 5, 29, 23, 34, 53)),
#  (869, 'SUSPECTS QUILLS', datetime.datetime(2005, 5, 25, 21, 21, 56), datetime.datetime(2005, 5, 30, 22, 41, 56)),
#  (177, 'CONNECTICUT TRAMP', datetime.datetime(2005, 5, 25, 21, 42, 46), datetime.datetime(2005, 5, 30, 23, 25, 46)),
#  (738, 'ROCKETEER MOTHER', datetime.datetime(2005, 5, 25, 21, 46, 54), datetime.datetime(2005, 5, 31, 21, 2, 54)),
#  (89, 'BORROWERS BEDAZZLED', datetime.datetime(2005, 5, 25, 21, 48, 30), datetime.datetime(2005, 5, 30, 0, 26, 30)),
#  (500, 'KISS GLORY', datetime.datetime(2005, 5, 25, 22, 2, 30), datetime.datetime(2005, 5, 31, 18, 6, 30)),
#  (898, 'TOURIST PELICAN', datetime.datetime(2005, 5, 25, 22, 48, 22), datetime.datetime(2005, 5, 29, 20, 21, 22)),
#  (73, 'BINGO TALENTED', datetime.datetime(2005, 5, 25, 23, 0, 21), datetime.datetime(2005, 5, 29, 17, 12, 21)),
#  (142, 'CHICKEN HELLFIGHTERS', datetime.datetime(2005, 5, 25, 23, 34, 22), datetime.datetime(2005, 5, 27, 1, 10, 22)),
#  (963, 'WATCH TRACY', datetime.datetime(2005, 5, 25, 23, 43, 47), datetime.datetime(2005, 5, 29, 0, 46, 47)),
#  (186, 'CRAFT OUTFIELD', datetime.datetime(2005, 5, 25, 23, 45, 52), datetime.datetime(2005, 5, 27, 21, 41, 52)),
#  (852, 'STRANGELOVE DESIRE', datetime.datetime(2005, 5, 25, 23, 59, 3), datetime.datetime(2005, 5, 31, 2, 56, 3)),
#  (138, 'CHARIOTS CONSPIRACY', datetime.datetime(2005, 5, 26, 0, 17, 50), datetime.datetime(2005, 5, 29, 23, 21, 50)),
#  (646, 'OUTBREAK DIVINE', datetime.datetime(2005, 5, 26, 0, 37, 28), datetime.datetime(2005, 5, 30, 6, 28, 28)),
#  (849, 'STORM HAPPINESS', datetime.datetime(2005, 5, 26, 0, 47, 47), datetime.datetime(2005, 5, 27, 21, 28, 47)),
#  (299, 'FACTORY DRAGON', datetime.datetime(2005, 5, 26, 0, 55, 56), datetime.datetime(2005, 5, 29, 23, 18, 56)),
#  (702, 'PULP BEVERLY', datetime.datetime(2005, 5, 26, 1, 19, 5), datetime.datetime(2005, 5, 27, 23, 43, 5)),
#  (197, 'CRUSADE HONEY', datetime.datetime(2005, 5, 26, 1, 25, 21), datetime.datetime(2005, 5, 26, 21, 17, 21)),
#  (757, 'SAGEBRUSH CLUELESS', datetime.datetime(2005, 5, 26, 1, 34, 28), datetime.datetime(2005, 5, 29, 4, 0, 28)),
#  (646, 'OUTBREAK DIVINE', datetime.datetime(2005, 5, 26, 1, 51, 48), datetime.datetime(2005, 5, 27, 5, 42, 48)),
#  (272, 'EDGE KISSING', datetime.datetime(2005, 5, 26, 2, 2, 5), datetime.datetime(2005, 5, 27, 3, 38, 5)),
#  (239, 'DOGMA FAMILY', datetime.datetime(2005, 5, 26, 2, 26, 49), datetime.datetime(2005, 5, 28, 0, 32, 49)),
#  (850, 'STORY SIDE', datetime.datetime(2005, 5, 26, 2, 49, 11), datetime.datetime(2005, 5, 31, 1, 28, 11)),
#  (190, 'CREEPERS KANE', datetime.datetime(2005, 5, 26, 2, 50, 31), datetime.datetime(2005, 5, 27, 3, 7, 31)),
#  (382, 'GRIT CLOCKWORK', datetime.datetime(2005, 5, 26, 3, 9, 30), datetime.datetime(2005, 5, 27, 1, 37, 30)),
#  (630, 'NOTTING SPEAKEASY', datetime.datetime(2005, 5, 26, 3, 17, 42), datetime.datetime(2005, 5, 29, 4, 11, 42)),
#  (786, 'SHEPHERD MIDSUMMER', datetime.datetime(2005, 5, 26, 3, 42, 10), datetime.datetime(2005, 5, 28, 1, 37, 10)),
#  (862, 'SUMMER SCARFACE', datetime.datetime(2005, 5, 26, 3, 44, 10), datetime.datetime(2005, 5, 28, 7, 13, 10)),
#  (527, 'LOLA AGENT', datetime.datetime(2005, 5, 26, 4, 47, 6), datetime.datetime(2005, 5, 29, 6, 34, 6)),
#  (429, 'HONEY TIES', datetime.datetime(2005, 5, 26, 5, 29, 49), datetime.datetime(2005, 5, 28, 10, 10, 49)),
#  (734, 'ROAD ROXANNE', datetime.datetime(2005, 5, 26, 5, 47, 12), datetime.datetime(2005, 5, 26, 23, 48, 12)),
#  (219, 'DEEP CRUSADE', datetime.datetime(2005, 5, 26, 6, 1, 41), datetime.datetime(2005, 5, 27, 6, 11, 41)),
#  (951, 'VOYAGE LEGALLY', datetime.datetime(2005, 5, 26, 6, 14, 6), datetime.datetime(2005, 5, 28, 5, 33, 6)),
#  (851, 'STRAIGHT HOURS', datetime.datetime(2005, 5, 26, 6, 41, 48), datetime.datetime(2005, 5, 30, 6, 21, 48)),
#  (295, 'EXPENDABLE STALLION', datetime.datetime(2005, 5, 26, 6, 52, 33), datetime.datetime(2005, 5, 30, 4, 8, 33)),
#  (112, 'CALENDAR GUNFIGHT', datetime.datetime(2005, 5, 26, 6, 52, 36), datetime.datetime(2005, 5, 31, 2, 47, 36)),
#  (43, 'ATLANTIS CAUSE', datetime.datetime(2005, 5, 26, 6, 55, 58), datetime.datetime(2005, 5, 27, 10, 54, 58)),
#  (462, 'INSIDER ARIZONA', datetime.datetime(2005, 5, 26, 7, 11, 58), datetime.datetime(2005, 5, 28, 9, 6, 58)),
#  (856, 'STREETCAR INTENTIONS', datetime.datetime(2005, 5, 26, 7, 12, 21), datetime.datetime(2005, 5, 31, 12, 7, 21)),
#  (401, 'HAROLD FRENCH', datetime.datetime(2005, 5, 26, 7, 30, 37), datetime.datetime(2005, 5, 30, 8, 11, 37)),
#  (68, 'BETRAYED REAR', datetime.datetime(2005, 5, 26, 7, 59, 37), datetime.datetime(2005, 5, 29, 9, 43, 37)),
#  (374, 'GRAFFITI LOVE', datetime.datetime(2005, 5, 26, 8, 1, 54), datetime.datetime(2005, 5, 27, 6, 26, 54)),
#  (21, 'AMERICAN CIRCUS', datetime.datetime(2005, 5, 26, 8, 4, 38), datetime.datetime(2005, 5, 27, 9, 32, 38)),
#  (803, 'SLACKER LIAISONS', datetime.datetime(2005, 5, 26, 8, 10, 22), datetime.datetime(2005, 5, 27, 3, 55, 22)),
#  (159, 'CLOSER BANG', datetime.datetime(2005, 5, 26, 8, 14, 1), datetime.datetime(2005, 5, 27, 9, 0, 1)),
#  (391, 'HALF OUTFIELD', datetime.datetime(2005, 5, 26, 8, 14, 15), datetime.datetime(2005, 5, 27, 12, 12, 15)),
#  (872, 'SWEET BROTHERHOOD', datetime.datetime(2005, 5, 26, 8, 33, 10), datetime.datetime(2005, 5, 28, 14, 9, 10)),
#  (167, 'COMA HEAD', datetime.datetime(2005, 5, 26, 8, 34, 41), datetime.datetime(2005, 5, 30, 12, 46, 41)),
#  (329, 'FORREST SONS', datetime.datetime(2005, 5, 26, 8, 44, 8), datetime.datetime(2005, 5, 31, 12, 33, 8)),
#  (319, 'FISH OPUS', datetime.datetime(2005, 5, 26, 8, 48, 49), datetime.datetime(2005, 5, 31, 4, 6, 49)),
#  (149, 'CHRISTMAS MOONSHINE', datetime.datetime(2005, 5, 26, 9, 2, 47), datetime.datetime(2005, 5, 28, 9, 45, 47)),
#  (961, 'WASH HEAVENLY', datetime.datetime(2005, 5, 26, 9, 24, 26), datetime.datetime(2005, 5, 31, 3, 24, 26)),
#  (676, 'PHILADELPHIA WIFE', datetime.datetime(2005, 5, 26, 9, 41, 45), datetime.datetime(2005, 5, 28, 4, 40, 45)),
#  (783, 'SHANE DARKNESS', datetime.datetime(2005, 5, 26, 10, 14, 9), datetime.datetime(2005, 5, 29, 5, 57, 9)),
#  (602, 'MOURNING PURPLE', datetime.datetime(2005, 5, 26, 10, 14, 38), datetime.datetime(2005, 5, 31, 8, 36, 38)),
#  (686, 'PLUTO OLEANDER', datetime.datetime(2005, 5, 26, 10, 15, 23), datetime.datetime(2005, 5, 30, 11, 43, 23)),
#  (911, 'TRIP NEWTON', datetime.datetime(2005, 5, 26, 10, 44, 4), datetime.datetime(2005, 5, 31, 13, 26, 4)),
#  (48, 'BACKLASH UNDEFEATED', datetime.datetime(2005, 5, 26, 10, 51, 46), datetime.datetime(2005, 5, 30, 7, 24, 46)),
#  (251, 'DRAGONFLY STRANGERS', datetime.datetime(2005, 5, 26, 11, 19, 20), datetime.datetime(2005, 5, 31, 11, 56, 20)),
#  (242, 'DOOM DANCING', datetime.datetime(2005, 5, 26, 11, 31, 50), datetime.datetime(2005, 5, 30, 15, 22, 50)),
#  (878, 'TEEN APOLLO', datetime.datetime(2005, 5, 26, 11, 31, 59), datetime.datetime(2005, 5, 27, 7, 27, 59)),
#  (646, 'OUTBREAK DIVINE', datetime.datetime(2005, 5, 26, 11, 38, 5), datetime.datetime(2005, 5, 27, 8, 42, 5)),
#  (156, 'CLERKS ANGELS', datetime.datetime(2005, 5, 26, 11, 43, 44), datetime.datetime(2005, 5, 28, 17, 28, 44)),
#  (280, 'EMPIRE MALKOVICH', datetime.datetime(2005, 5, 26, 11, 53, 49), datetime.datetime(2005, 5, 28, 13, 55, 49)),
#  (54, 'BANGER PINOCCHIO', datetime.datetime(2005, 5, 26, 12, 15, 13), datetime.datetime(2005, 5, 29, 18, 10, 13)),
#  (112, 'CALENDAR GUNFIGHT', datetime.datetime(2005, 5, 26, 12, 30, 22), datetime.datetime(2005, 5, 27, 6, 49, 22)),
#  (970, 'WESTWARD SEABISCUIT', datetime.datetime(2005, 5, 26, 12, 49, 1), datetime.datetime(2005, 5, 28, 11, 43, 1)),
#  (232, 'DIRTY ACE', datetime.datetime(2005, 5, 26, 13, 40, 40), datetime.datetime(2005, 5, 31, 11, 58, 40)),
#  (668, 'PEAK FOREVER', datetime.datetime(2005, 5, 26, 13, 46, 59), datetime.datetime(2005, 5, 27, 9, 58, 59)),
#  (621, 'NETWORK PEAK', datetime.datetime(2005, 5, 26, 13, 57, 7), datetime.datetime(2005, 5, 29, 10, 12, 7)),
#  (892, 'TITANIC BOONDOCK', datetime.datetime(2005, 5, 26, 14, 1, 5), datetime.datetime(2005, 5, 28, 13, 38, 5)),
#  (416, 'HIGHBALL POTTER', datetime.datetime(2005, 5, 26, 14, 7, 58), datetime.datetime(2005, 5, 31, 14, 3, 58)),
#  (530, 'LORD ARIZONA', datetime.datetime(2005, 5, 26, 14, 19, 9), datetime.datetime(2005, 5, 28, 17, 47, 9)),
#  (81, 'BLINDNESS GUN', datetime.datetime(2005, 5, 26, 14, 30, 24), datetime.datetime(2005, 5, 27, 8, 50, 24)),
#  (948, 'VOICE PEACH', datetime.datetime(2005, 5, 26, 14, 35, 40), datetime.datetime(2005, 5, 29, 17, 17, 40)),
#  (650, 'PACIFIC AMISTAD', datetime.datetime(2005, 5, 26, 14, 43, 14), datetime.datetime(2005, 5, 27, 12, 21, 14)),
#  (398, 'HANOVER GALAXY', datetime.datetime(2005, 5, 26, 14, 43, 48), datetime.datetime(2005, 5, 31, 9, 19, 48)),
#  (719, 'RECORDS ZORRO', datetime.datetime(2005, 5, 26, 14, 52, 15), datetime.datetime(2005, 5, 27, 12, 45, 15)),
#  (702, 'PULP BEVERLY', datetime.datetime(2005, 5, 26, 15, 20, 58), datetime.datetime(2005, 5, 31, 15, 58, 58)),
#  (563, 'MASSACRE USUAL', datetime.datetime(2005, 5, 26, 15, 27, 5), datetime.datetime(2005, 5, 29, 16, 25, 5)),
#  (773, 'SEABISCUIT PUNK', datetime.datetime(2005, 5, 26, 15, 28, 14), datetime.datetime(2005, 5, 30, 18, 38, 14)),
#  (96, 'BREAKING HOME', datetime.datetime(2005, 5, 26, 15, 42, 20), datetime.datetime(2005, 5, 31, 13, 21, 20)),
#  (927, 'UPRISING UPTOWN', datetime.datetime(2005, 5, 26, 15, 46, 56), datetime.datetime(2005, 5, 28, 15, 49, 56)),
#  (256, 'DROP WATERFRONT', datetime.datetime(2005, 5, 26, 15, 47, 40), datetime.datetime(2005, 5, 30, 10, 7, 40)),
#  (449, 'IDENTITY LOVER', datetime.datetime(2005, 5, 26, 16, 0, 49), datetime.datetime(2005, 5, 27, 10, 12, 49)),
#  (727, 'RESURRECTION SILVERADO', datetime.datetime(2005, 5, 26, 16, 8, 5), datetime.datetime(2005, 5, 27, 10, 55, 5)),
#  (268, 'EARLY HOME', datetime.datetime(2005, 5, 26, 16, 16, 21), datetime.datetime(2005, 5, 30, 16, 53, 21)),
#  (374, 'GRAFFITI LOVE', datetime.datetime(2005, 5, 26, 16, 19, 8), datetime.datetime(2005, 5, 27, 14, 35, 8)),
#  (767, 'SCALAWAG DUCK', datetime.datetime(2005, 5, 26, 16, 19, 46), datetime.datetime(2005, 5, 27, 15, 59, 46)),
#  (349, 'GANGS PRIDE', datetime.datetime(2005, 5, 26, 16, 29, 36), datetime.datetime(2005, 5, 29, 18, 49, 36)),
#  (308, 'FERRIS MOTHER', datetime.datetime(2005, 5, 26, 17, 32, 11), datetime.datetime(2005, 5, 28, 22, 54, 11)),
#  (413, 'HEDWIG ALTER', datetime.datetime(2005, 5, 26, 18, 36, 58), datetime.datetime(2005, 5, 27, 23, 42, 58)),
#  (269, 'EARRING INSTINCT', datetime.datetime(2005, 5, 26, 18, 49, 35), datetime.datetime(2005, 5, 27, 18, 11, 35)),
#  (772, 'SEA VIRGIN', datetime.datetime(2005, 5, 26, 19, 5, 5), datetime.datetime(2005, 5, 31, 19, 19, 5)),
#  (545, 'MADNESS ATTACKS', datetime.datetime(2005, 5, 26, 19, 41, 40), datetime.datetime(2005, 5, 31, 16, 58, 40)),
#  (534, 'LOUISIANA HARRY', datetime.datetime(2005, 5, 26, 20, 1, 9), datetime.datetime(2005, 5, 28, 15, 9, 9)),
#  (609, 'MUSCLE BRIGHT', datetime.datetime(2005, 5, 26, 20, 8, 33), datetime.datetime(2005, 5, 30, 0, 32, 33)),
#  (603, 'MOVIE SHAKESPEARE', datetime.datetime(2005, 5, 26, 20, 29, 57), datetime.datetime(2005, 5, 28, 17, 20, 57)),
#  (878, 'TEEN APOLLO', datetime.datetime(2005, 5, 26, 20, 33, 20), datetime.datetime(2005, 5, 27, 18, 23, 20)),
#  (349, 'GANGS PRIDE', datetime.datetime(2005, 5, 26, 20, 48, 48), datetime.datetime(2005, 5, 27, 19, 52, 48)),
#  (241, 'DONNIE ALLEY', datetime.datetime(2005, 5, 26, 20, 52, 26), datetime.datetime(2005, 5, 29, 22, 8, 26)),
#  (956, 'WANDA CHAMBER', datetime.datetime(2005, 5, 26, 20, 55, 36), datetime.datetime(2005, 5, 28, 0, 25, 36)),
#  (246, 'DOUBTFIRE LABYRINTH', datetime.datetime(2005, 5, 26, 21, 16, 52), datetime.datetime(2005, 5, 27, 23, 41, 52)),
#  (610, 'MUSIC BOONDOCK', datetime.datetime(2005, 5, 26, 21, 31, 57), datetime.datetime(2005, 5, 28, 19, 37, 57)),
#  (902, 'TRADING PINOCCHIO', datetime.datetime(2005, 5, 26, 22, 56, 19), datetime.datetime(2005, 5, 29, 1, 29, 19)),
#  (625, 'NONE SPIKING', datetime.datetime(2005, 5, 26, 23, 9, 41), datetime.datetime(2005, 5, 28, 22, 49, 41)),
#  (624, 'NIGHTMARE CHILL', datetime.datetime(2005, 5, 26, 23, 12, 55), datetime.datetime(2005, 5, 29, 23, 33, 55)),
#  (838, 'STAGECOACH ARMAGEDDON', datetime.datetime(2005, 5, 26, 23, 22, 55), datetime.datetime(2005, 5, 29, 23, 25, 55)),
#  (664, 'PATRIOT ROMAN', datetime.datetime(2005, 5, 26, 23, 52, 13), datetime.datetime(2005, 5, 30, 18, 55, 13)),
#  (243, 'DOORS PRESIDENT', datetime.datetime(2005, 5, 27, 0, 9, 24), datetime.datetime(2005, 5, 28, 4, 30, 24)),
#  (514, 'LEBOWSKI SOLDIERS', datetime.datetime(2005, 5, 27, 0, 49, 27), datetime.datetime(2005, 5, 30, 3, 12, 27)),
#  (738, 'ROCKETEER MOTHER', datetime.datetime(2005, 5, 27, 1, 0, 4), datetime.datetime(2005, 5, 30, 4, 27, 4)),
#  (551, 'MAIDEN HOME', datetime.datetime(2005, 5, 27, 1, 9, 55), datetime.datetime(2005, 5, 31, 7, 1, 55)),
#  (583, 'MISSION ZOOLANDER', datetime.datetime(2005, 5, 27, 1, 57, 14), datetime.datetime(2005, 5, 31, 4, 19, 14)),
#  (865, 'SUNRISE LEAGUE', datetime.datetime(2005, 5, 27, 3, 3, 7), datetime.datetime(2005, 5, 29, 3, 54, 7)),
#  (393, 'HALLOWEEN NUTS', datetime.datetime(2005, 5, 27, 3, 15, 23), datetime.datetime(2005, 5, 29, 22, 43, 23)),
#  (875, 'TALENTED HOMICIDE', datetime.datetime(2005, 5, 27, 4, 11, 4), datetime.datetime(2005, 5, 29, 1, 28, 4)),
#  (727, 'RESURRECTION SILVERADO', datetime.datetime(2005, 5, 27, 4, 13, 41), datetime.datetime(2005, 5, 28, 8, 34, 41)),
#  (505, 'LABYRINTH LEAGUE', datetime.datetime(2005, 5, 27, 4, 30, 22), datetime.datetime(2005, 5, 29, 10, 13, 22)),
#  (305, 'FATAL HAUNTED', datetime.datetime(2005, 5, 27, 4, 32, 25), datetime.datetime(2005, 5, 31, 9, 50, 25)),
#  (355, 'GHOSTBUSTERS ELF', datetime.datetime(2005, 5, 27, 4, 40, 33), datetime.datetime(2005, 5, 28, 9, 56, 33)),
#  (641, 'ORANGE GRAPES', datetime.datetime(2005, 5, 27, 4, 53, 11), datetime.datetime(2005, 5, 28, 6, 33, 11)),
#  (953, 'WAIT CIDER', datetime.datetime(2005, 5, 27, 5, 48, 19), datetime.datetime(2005, 5, 29, 9, 5, 19)),
#  (628, 'NORTHWEST POLISH', datetime.datetime(2005, 5, 27, 6, 32, 30), datetime.datetime(2005, 5, 30, 6, 24, 30)),
#  (966, 'WEDDING APOLLO', datetime.datetime(2005, 5, 27, 6, 37, 15), datetime.datetime(2005, 5, 30, 7, 4, 15)),
#  (418, 'HOBBIT ALIEN', datetime.datetime(2005, 5, 27, 6, 43, 59), datetime.datetime(2005, 5, 29, 11, 28, 59)),
#  (255, 'DRIVING POLISH', datetime.datetime(2005, 5, 27, 6, 48, 33), datetime.datetime(2005, 5, 29, 3, 55, 33)),
#  (1, 'ACADEMY DINOSAUR', datetime.datetime(2005, 5, 27, 7, 3, 28), datetime.datetime(2005, 5, 31, 8, 1, 28)),
#  (932, 'VALLEY PACKER', datetime.datetime(2005, 5, 27, 7, 14), datetime.datetime(2005, 5, 28, 12, 22)),
#  (182, 'CONTROL ANTHEM', datetime.datetime(2005, 5, 27, 7, 20, 12), datetime.datetime(2005, 5, 31, 10, 44, 12)),
#  (753, 'RUSH GOODFELLAS', datetime.datetime(2005, 5, 27, 7, 37, 2), datetime.datetime(2005, 5, 30, 5, 43, 2)),
#  (484, 'JERK PAYCHECK', datetime.datetime(2005, 5, 27, 9, 23, 22), datetime.datetime(2005, 5, 29, 15, 20, 22)),
#  (603, 'MOVIE SHAKESPEARE', datetime.datetime(2005, 5, 27, 9, 43, 25), datetime.datetime(2005, 5, 31, 12, 0, 25)),
#  (949, 'VOLCANO TEXAS', datetime.datetime(2005, 5, 27, 10, 12), datetime.datetime(2005, 5, 31, 15, 3)),
#  (344, 'FURY MURDER', datetime.datetime(2005, 5, 27, 10, 23, 25), datetime.datetime(2005, 5, 30, 15, 27, 25)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 27, 10, 26, 31), datetime.datetime(2005, 5, 30, 8, 32, 31)),
#  (96, 'BREAKING HOME', datetime.datetime(2005, 5, 27, 10, 37, 27), datetime.datetime(2005, 5, 30, 5, 45, 27)),
#  (30, 'ANYTHING SAVANNAH', datetime.datetime(2005, 5, 27, 11, 18, 25), datetime.datetime(2005, 5, 28, 7, 10, 25)),
#  (164, 'COAST RAINBOW', datetime.datetime(2005, 5, 27, 11, 45, 49), datetime.datetime(2005, 5, 31, 13, 42, 49)),
#  (228, 'DETECTIVE VISION', datetime.datetime(2005, 5, 27, 11, 47, 4), datetime.datetime(2005, 5, 29, 10, 14, 4)),
#  (912, 'TROJAN TOMORROW', datetime.datetime(2005, 5, 27, 12, 29, 2), datetime.datetime(2005, 5, 28, 17, 36, 2)),
#  (120, 'CARIBBEAN LIBERTY', datetime.datetime(2005, 5, 27, 12, 48, 38), datetime.datetime(2005, 5, 29, 15, 27, 38)),
#  (57, 'BASIC EASY', datetime.datetime(2005, 5, 27, 12, 51, 44), datetime.datetime(2005, 5, 31, 8, 34, 44)),
#  (471, 'ISLAND EXORCIST', datetime.datetime(2005, 5, 27, 12, 57, 55), datetime.datetime(2005, 5, 29, 17, 55, 55)),
#  (101, 'BROTHERHOOD BLANKET', datetime.datetime(2005, 5, 27, 13, 17, 18), datetime.datetime(2005, 5, 30, 8, 53, 18)),
#  (868, 'SUPERFLY TRIP', datetime.datetime(2005, 5, 27, 13, 28, 52), datetime.datetime(2005, 5, 29, 11, 47, 52)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 27, 13, 31, 51), datetime.datetime(2005, 5, 30, 16, 58, 51)),
#  (462, 'INSIDER ARIZONA', datetime.datetime(2005, 5, 27, 13, 46, 46), datetime.datetime(2005, 5, 30, 12, 43, 46)),
#  (240, 'DOLLS RAGE', datetime.datetime(2005, 5, 27, 13, 57, 38), datetime.datetime(2005, 5, 31, 18, 23, 38)),
#  (314, 'FIGHT JAWBREAKER', datetime.datetime(2005, 5, 27, 13, 57, 39), datetime.datetime(2005, 5, 28, 11, 57, 39)),
#  (307, 'FELLOWSHIP AUTUMN', datetime.datetime(2005, 5, 27, 14, 17, 23), datetime.datetime(2005, 5, 29, 15, 7, 23)),
#  (228, 'DETECTIVE VISION', datetime.datetime(2005, 5, 27, 14, 48, 20), datetime.datetime(2005, 5, 31, 14, 39, 20)),
#  (809, 'SLIPPER FIDELITY', datetime.datetime(2005, 5, 27, 14, 51, 45), datetime.datetime(2005, 5, 28, 19, 7, 45)),
#  (517, 'LESSON CLEOPATRA', datetime.datetime(2005, 5, 27, 15, 2, 10), datetime.datetime(2005, 5, 29, 10, 34, 10)),
#  (487, 'JINGLE SAGEBRUSH', datetime.datetime(2005, 5, 27, 15, 7, 27), datetime.datetime(2005, 5, 29, 20, 1, 27)),
#  (735, 'ROBBERS JOON', datetime.datetime(2005, 5, 27, 16, 10, 58), datetime.datetime(2005, 5, 31, 17, 24, 58)),
#  (248, 'DOZEN LION', datetime.datetime(2005, 5, 27, 16, 40, 29), datetime.datetime(2005, 5, 29, 16, 20, 29)),
#  (951, 'VOYAGE LEGALLY', datetime.datetime(2005, 5, 27, 16, 40, 40), datetime.datetime(2005, 5, 30, 19, 55, 40)),
#  (941, 'VIDEOTAPE ARSENIC', datetime.datetime(2005, 5, 27, 17, 21, 4), datetime.datetime(2005, 5, 30, 21, 26, 4)),
#  (973, 'WIFE TURN', datetime.datetime(2005, 5, 27, 18, 0, 35), datetime.datetime(2005, 5, 29, 16, 15, 35)),
#  (346, 'GALAXY SWEETHEARTS', datetime.datetime(2005, 5, 27, 18, 11, 5), datetime.datetime(2005, 5, 30, 22, 45, 5)),
#  (319, 'FISH OPUS', datetime.datetime(2005, 5, 27, 18, 12, 13), datetime.datetime(2005, 5, 30, 12, 30, 13)),
#  (382, 'GRIT CLOCKWORK', datetime.datetime(2005, 5, 27, 18, 42, 57), datetime.datetime(2005, 5, 30, 22, 35, 57)),
#  (45, 'ATTRACTION NEWTON', datetime.datetime(2005, 5, 27, 19, 27, 54), datetime.datetime(2005, 5, 29, 1, 7, 54)),
#  (656, 'PAPI NECKLACE', datetime.datetime(2005, 5, 27, 19, 30, 33), datetime.datetime(2005, 5, 30, 20, 53, 33)),
#  (967, 'WEEKEND PERSONAL', datetime.datetime(2005, 5, 27, 19, 31, 16), datetime.datetime(2005, 5, 29, 23, 6, 16)),
#  (767, 'SCALAWAG DUCK', datetime.datetime(2005, 5, 27, 19, 31, 36), datetime.datetime(2005, 5, 30, 15, 46, 36)),
#  (130, 'CELEBRITY HORN', datetime.datetime(2005, 5, 27, 20, 0, 4), datetime.datetime(2005, 5, 29, 22, 47, 4)),
#  (921, 'UNCUT SUICIDES', datetime.datetime(2005, 5, 27, 20, 2, 3), datetime.datetime(2005, 5, 28, 16, 14, 3)),
#  (290, 'EVERYONE CRAFT', datetime.datetime(2005, 5, 27, 20, 42, 44), datetime.datetime(2005, 5, 30, 0, 49, 44)),
#  (388, 'GUNFIGHT MOON', datetime.datetime(2005, 5, 27, 20, 57, 7), datetime.datetime(2005, 5, 29, 15, 52, 7)),
#  (629, 'NOTORIOUS REUNION', datetime.datetime(2005, 5, 27, 21, 32, 42), datetime.datetime(2005, 5, 31, 0, 39, 42)),
#  (295, 'EXPENDABLE STALLION', datetime.datetime(2005, 5, 27, 21, 36, 15), datetime.datetime(2005, 5, 29, 21, 7, 15)),
#  (322, 'FLATLINERS KILLER', datetime.datetime(2005, 5, 27, 22, 11, 56), datetime.datetime(2005, 5, 31, 19, 7, 56)),
#  (554, 'MALKOVICH PET', datetime.datetime(2005, 5, 27, 22, 16, 26), datetime.datetime(2005, 5, 28, 19, 58, 26)),
#  (93, 'BRANNIGAN SUNRISE', datetime.datetime(2005, 5, 27, 22, 38, 20), datetime.datetime(2005, 5, 31, 18, 39, 20)),
#  (15, 'ALIEN CENTER', datetime.datetime(2005, 5, 27, 22, 49, 27), datetime.datetime(2005, 5, 30, 17, 46, 27)),
#  (330, 'FORRESTER COMANCHEROS', datetime.datetime(2005, 5, 27, 23, 0, 25), datetime.datetime(2005, 5, 28, 21, 30, 25)),
#  (684, 'PIZZA JUMANJI', datetime.datetime(2005, 5, 27, 23, 26, 45), datetime.datetime(2005, 5, 29, 21, 16, 45)),
#  (522, 'LIFE TWISTED', datetime.datetime(2005, 5, 27, 23, 40, 52), datetime.datetime(2005, 5, 28, 22, 40, 52)),
#  (396, 'HANGING DEEP', datetime.datetime(2005, 5, 27, 23, 51, 12), datetime.datetime(2005, 5, 28, 20, 26, 12)),
#  (826, 'SPEED SUIT', datetime.datetime(2005, 5, 28, 0, 0, 30), datetime.datetime(2005, 5, 28, 19, 18, 30)),
#  (422, 'HOLLOW JEOPARDY', datetime.datetime(2005, 5, 28, 0, 9, 12), datetime.datetime(2005, 5, 31, 4, 44, 12)),
#  (771, 'SCORPION APOLLO', datetime.datetime(2005, 5, 28, 0, 9, 56), datetime.datetime(2005, 5, 30, 22, 32, 56)),
#  (293, 'EXORCIST STING', datetime.datetime(2005, 5, 28, 0, 13, 35), datetime.datetime(2005, 5, 29, 0, 11, 35)),
#  (435, 'HOTEL HAPPINESS', datetime.datetime(2005, 5, 28, 0, 24, 58), datetime.datetime(2005, 5, 28, 22, 34, 58)),
#  (40, 'ARMY FLINTSTONES', datetime.datetime(2005, 5, 28, 0, 34, 11), datetime.datetime(2005, 5, 30, 18, 40, 11)),
#  (226, 'DESTINY SATURDAY', datetime.datetime(2005, 5, 28, 0, 40, 48), datetime.datetime(2005, 5, 29, 6, 7, 48)),
#  (101, 'BROTHERHOOD BLANKET', datetime.datetime(2005, 5, 28, 1, 1, 21), datetime.datetime(2005, 5, 30, 21, 20, 21)),
#  (982, 'WOMEN DORADO', datetime.datetime(2005, 5, 28, 1, 5, 25), datetime.datetime(2005, 5, 31, 20, 4, 25)),
#  (131, 'CENTER DINOSAUR', datetime.datetime(2005, 5, 28, 1, 9, 36), datetime.datetime(2005, 5, 30, 6, 14, 36)),
#  (688, 'POLISH BROOKLYN', datetime.datetime(2005, 5, 28, 1, 34, 43), datetime.datetime(2005, 5, 31, 1, 2, 43)),
#  (659, 'PARK CITIZEN', datetime.datetime(2005, 5, 28, 1, 35, 25), datetime.datetime(2005, 5, 28, 22, 12, 25)),
#  (452, 'ILLUSION AMELIE', datetime.datetime(2005, 5, 28, 2, 5, 34), datetime.datetime(2005, 5, 30, 23, 3, 34)),
#  (15, 'ALIEN CENTER', datetime.datetime(2005, 5, 28, 2, 6, 37), datetime.datetime(2005, 5, 29, 6, 57, 37)),
#  (748, 'RUGRATS SHAKESPEARE', datetime.datetime(2005, 5, 28, 2, 51, 12), datetime.datetime(2005, 5, 31, 6, 27, 12)),
#  (945, 'VIRGINIAN PLUTO', datetime.datetime(2005, 5, 28, 2, 52, 14), datetime.datetime(2005, 5, 30, 21, 20, 14)),
#  (50, 'BAKED CLEOPATRA', datetime.datetime(2005, 5, 28, 3, 8, 10), datetime.datetime(2005, 5, 29, 7, 22, 10)),
#  (52, 'BALLROOM MOCKINGBIRD', datetime.datetime(2005, 5, 28, 3, 17, 57), datetime.datetime(2005, 5, 29, 6, 33, 57)),
#  (891, 'TIMBERLAND SKY', datetime.datetime(2005, 5, 28, 3, 18, 2), datetime.datetime(2005, 5, 30, 5, 32, 2)),
#  (524, 'LION UNCUT', datetime.datetime(2005, 5, 28, 3, 32, 22), datetime.datetime(2005, 5, 28, 22, 37, 22)),
#  (702, 'PULP BEVERLY', datetime.datetime(2005, 5, 28, 3, 33, 20), datetime.datetime(2005, 5, 31, 4, 23, 20)),
#  (415, 'HIGH ENCINO', datetime.datetime(2005, 5, 28, 3, 53, 26), datetime.datetime(2005, 5, 31, 5, 58, 26)),
#  (428, 'HOMICIDE PEACH', datetime.datetime(2005, 5, 28, 3, 57, 28), datetime.datetime(2005, 5, 31, 5, 20, 28)),
#  (304, 'FARGO GANDHI', datetime.datetime(2005, 5, 28, 4, 27, 37), datetime.datetime(2005, 5, 30, 7, 52, 37)),
#  (575, 'MIDSUMMER GROUNDHOG', datetime.datetime(2005, 5, 28, 4, 34, 17), datetime.datetime(2005, 5, 30, 0, 35, 17)),
#  (247, 'DOWNHILL ENOUGH', datetime.datetime(2005, 5, 28, 5, 23, 38), datetime.datetime(2005, 5, 29, 8, 0, 38)),
#  (915, 'TRUMAN CRAZY', datetime.datetime(2005, 5, 28, 6, 16, 32), datetime.datetime(2005, 5, 31, 2, 48, 32)),
#  (751, 'RUNAWAY TENENBAUMS', datetime.datetime(2005, 5, 28, 6, 26, 16), datetime.datetime(2005, 5, 30, 2, 2, 16)),
#  (425, 'HOLY TADPOLE', datetime.datetime(2005, 5, 28, 8, 23, 16), datetime.datetime(2005, 5, 31, 3, 29, 16)),
#  (961, 'WASH HEAVENLY', datetime.datetime(2005, 5, 28, 8, 31, 14), datetime.datetime(2005, 5, 30, 7, 34, 14)),
#  (651, 'PACKER MADIGAN', datetime.datetime(2005, 5, 28, 9, 12, 9), datetime.datetime(2005, 5, 29, 5, 7, 9)),
#  (483, 'JERICHO MULAN', datetime.datetime(2005, 5, 28, 9, 57, 36), datetime.datetime(2005, 5, 31, 15, 44, 36)),
#  (249, 'DRACULA CRYSTAL', datetime.datetime(2005, 5, 28, 10, 15, 4), datetime.datetime(2005, 5, 30, 8, 32, 4)),
#  (1000, 'ZORRO ARK', datetime.datetime(2005, 5, 28, 11, 33, 46), datetime.datetime(2005, 5, 29, 8, 33, 46)),
#  (200, 'CURTAIN VIDEOTAPE', datetime.datetime(2005, 5, 28, 12, 3), datetime.datetime(2005, 5, 29, 13, 16)),
#  (309, 'FEUD FROGMEN', datetime.datetime(2005, 5, 28, 12, 5, 33), datetime.datetime(2005, 5, 30, 13, 45, 33)),
#  (19, 'AMADEUS HOLY', datetime.datetime(2005, 5, 28, 12, 8, 37), datetime.datetime(2005, 5, 29, 16, 25, 37)),
#  (83, 'BLUES INSTINCT', datetime.datetime(2005, 5, 28, 13, 11, 4), datetime.datetime(2005, 5, 29, 17, 20, 4)),
#  (139, 'CHASING FIGHT', datetime.datetime(2005, 5, 28, 13, 21, 8), datetime.datetime(2005, 5, 29, 16, 55, 8)),
#  (393, 'HALLOWEEN NUTS', datetime.datetime(2005, 5, 28, 13, 33, 23), datetime.datetime(2005, 5, 30, 17, 10, 23)),
#  (608, 'MURDER ANTITRUST', datetime.datetime(2005, 5, 28, 13, 41, 56), datetime.datetime(2005, 5, 30, 12, 0, 56)),
#  (179, 'CONQUERER NUTS', datetime.datetime(2005, 5, 28, 14, 0, 3), datetime.datetime(2005, 5, 29, 17, 10, 3)),
#  (715, 'RANGE MOONWALKER', datetime.datetime(2005, 5, 28, 14, 27, 51), datetime.datetime(2005, 5, 29, 13, 13, 51)),
#  (561, 'MASK PEACH', datetime.datetime(2005, 5, 28, 15, 2, 41), datetime.datetime(2005, 5, 30, 12, 54, 41)),
#  (273, 'EFFECT GLADIATOR', datetime.datetime(2005, 5, 28, 15, 18, 18), datetime.datetime(2005, 5, 31, 20, 15, 18)),
#  (471, 'ISLAND EXORCIST', datetime.datetime(2005, 5, 28, 15, 24, 54), datetime.datetime(2005, 5, 30, 14, 22, 54)),
#  (900, 'TOWN ARK', datetime.datetime(2005, 5, 28, 15, 49, 14), datetime.datetime(2005, 5, 31, 14, 29, 14)),
#  (253, 'DRIFTER COMMANDMENTS', datetime.datetime(2005, 5, 28, 15, 58, 12), datetime.datetime(2005, 5, 30, 21, 54, 12)),
#  (271, 'EASY GLADIATOR', datetime.datetime(2005, 5, 28, 16, 1, 28), datetime.datetime(2005, 5, 30, 11, 19, 28)),
#  (347, 'GAMES BOWFINGER', datetime.datetime(2005, 5, 28, 18, 14, 29), datetime.datetime(2005, 5, 29, 23, 48, 29)),
#  (914, 'TROUBLE DATE', datetime.datetime(2005, 5, 28, 18, 25, 2), datetime.datetime(2005, 5, 29, 18, 22, 2)),
#  (110, 'CABIN FLASH', datetime.datetime(2005, 5, 28, 18, 43, 26), datetime.datetime(2005, 5, 30, 13, 39, 26)),
#  (682, 'PITTSBURGH HUNCHBACK', datetime.datetime(2005, 5, 28, 18, 52, 11), datetime.datetime(2005, 5, 31, 15, 15, 11)),
#  (417, 'HILLS NEIGHBORS', datetime.datetime(2005, 5, 28, 19, 16, 14), datetime.datetime(2005, 5, 31, 16, 50, 14)),
#  (958, 'WARDROBE PHANTOM', datetime.datetime(2005, 5, 28, 19, 45, 40), datetime.datetime(2005, 5, 29, 21, 2, 40)),
#  (162, 'CLUELESS BUCKET', datetime.datetime(2005, 5, 28, 19, 46, 50), datetime.datetime(2005, 5, 30, 16, 29, 50)),
#  (267, 'EAGLES PANKY', datetime.datetime(2005, 5, 28, 20, 8, 47), datetime.datetime(2005, 5, 29, 14, 57, 47)),
#  (502, 'KNOCK WARLOCK', datetime.datetime(2005, 5, 28, 20, 15, 30), datetime.datetime(2005, 5, 30, 22, 2, 30)),
#  (73, 'BINGO TALENTED', datetime.datetime(2005, 5, 28, 20, 16, 20), datetime.datetime(2005, 5, 31, 16, 46, 20)),
#  (624, 'NIGHTMARE CHILL', datetime.datetime(2005, 5, 28, 20, 18, 24), datetime.datetime(2005, 5, 30, 16, 19, 24)),
#  (303, 'FANTASY TROOPERS', datetime.datetime(2005, 5, 28, 20, 27, 53), datetime.datetime(2005, 5, 31, 1, 36, 53)),
#  (309, 'FEUD FROGMEN', datetime.datetime(2005, 5, 28, 20, 53, 31), datetime.datetime(2005, 5, 30, 15, 26, 31)),
#  (227, 'DETAILS PACKER', datetime.datetime(2005, 5, 28, 21, 38, 39), datetime.datetime(2005, 5, 29, 21, 37, 39)),
#  (174, 'CONFIDENTIAL INTERVIEW', datetime.datetime(2005, 5, 28, 21, 49, 2), datetime.datetime(2005, 5, 31, 3, 7, 2)),
#  (772, 'SEA VIRGIN', datetime.datetime(2005, 5, 28, 21, 54, 45), datetime.datetime(2005, 5, 29, 22, 32, 45)),
#  (506, 'LADY STAGE', datetime.datetime(2005, 5, 28, 22, 27, 51), datetime.datetime(2005, 5, 29, 20, 36, 51)),
#  (694, 'PREJUDICE OLEANDER', datetime.datetime(2005, 5, 28, 23, 53, 18), datetime.datetime(2005, 5, 29, 19, 14, 18)),
#  (532, 'LOSER HUSTLER', datetime.datetime(2005, 5, 29, 0, 27, 10), datetime.datetime(2005, 5, 30, 2, 29, 10)),
#  (377, 'GREASE YOUTH', datetime.datetime(2005, 5, 29, 0, 32, 9), datetime.datetime(2005, 5, 31, 23, 53, 9)),
#  (111, 'CADDYSHACK JEDI', datetime.datetime(2005, 5, 29, 2, 18, 54), datetime.datetime(2005, 5, 30, 5, 54, 54)),
#  (560, 'MARS ROMAN', datetime.datetime(2005, 5, 29, 2, 27, 30), datetime.datetime(2005, 5, 30, 1, 52, 30)),
#  (616, 'NATIONAL STORY', datetime.datetime(2005, 5, 29, 2, 48, 52), datetime.datetime(2005, 5, 30, 6, 21, 52)),
#  (179, 'CONQUERER NUTS', datetime.datetime(2005, 5, 29, 3, 18, 19), datetime.datetime(2005, 5, 30, 2, 45, 19)),
#  (688, 'POLISH BROOKLYN', datetime.datetime(2005, 5, 29, 3, 23, 47), datetime.datetime(2005, 5, 31, 21, 27, 47)),
#  (1000, 'ZORRO ARK', datetime.datetime(2005, 5, 29, 3, 49, 3), datetime.datetime(2005, 5, 31, 8, 29, 3)),
#  (912, 'TROJAN TOMORROW', datetime.datetime(2005, 5, 29, 4, 2, 24), datetime.datetime(2005, 5, 30, 3, 9, 24)),
#  (303, 'FANTASY TROOPERS', datetime.datetime(2005, 5, 29, 4, 37, 44), datetime.datetime(2005, 5, 30, 5, 48, 44)),
#  (247, 'DOWNHILL ENOUGH', datetime.datetime(2005, 5, 29, 5, 28, 47), datetime.datetime(2005, 5, 31, 11, 24, 47)),
#  (747, 'ROXANNE REBEL', datetime.datetime(2005, 5, 29, 5, 34, 44), datetime.datetime(2005, 5, 30, 5, 50, 44)),
#  (356, 'GIANT TROOPERS', datetime.datetime(2005, 5, 29, 6, 8, 15), datetime.datetime(2005, 5, 30, 7, 16, 15)),
#  (896, 'TOOTSIE PILOT', datetime.datetime(2005, 5, 29, 7, 25, 16), datetime.datetime(2005, 5, 30, 5, 21, 16)),
#  (555, 'MALLRATS UNITED', datetime.datetime(2005, 5, 29, 7, 32, 51), datetime.datetime(2005, 5, 30, 10, 8, 51)),
#  (253, 'DRIFTER COMMANDMENTS', datetime.datetime(2005, 5, 29, 9, 33, 33), datetime.datetime(2005, 5, 31, 11, 45, 33)),
#  (159, 'CLOSER BANG', datetime.datetime(2005, 5, 29, 9, 41, 40), datetime.datetime(2005, 5, 30, 13, 31, 40)),
#  (439, 'HUNCHBACK IMPOSSIBLE', datetime.datetime(2005, 5, 29, 11, 32, 15), datetime.datetime(2005, 5, 31, 17, 31, 15)),
#  (239, 'DOGMA FAMILY', datetime.datetime(2005, 5, 29, 11, 37, 35), datetime.datetime(2005, 5, 31, 16, 47, 35)),
#  (266, 'DYNAMITE TARZAN', datetime.datetime(2005, 5, 29, 13, 23, 26), datetime.datetime(2005, 5, 30, 7, 53, 26)),
#  (18, 'ALTER VICTORY', datetime.datetime(2005, 5, 29, 14, 23, 58), datetime.datetime(2005, 5, 30, 17, 44, 58)),
#  (8, 'AIRPORT POLLOCK', datetime.datetime(2005, 5, 29, 15, 8, 41), datetime.datetime(2005, 5, 30, 15, 51, 41)),
#  (166, 'COLOR PHILADELPHIA', datetime.datetime(2005, 5, 29, 16, 13, 55), datetime.datetime(2005, 5, 31, 16, 40, 55)),
#  (623, 'NEWTON LABYRINTH', datetime.datetime(2005, 5, 29, 16, 32, 10), datetime.datetime(2005, 5, 31, 18, 1, 10)),
#  (97, 'BRIDE INTRIGUE', datetime.datetime(2005, 5, 29, 17, 28, 12), datetime.datetime(2005, 5, 30, 14, 59, 12)),
#  (172, 'CONEHEADS SMOOCHY', datetime.datetime(2005, 5, 29, 17, 38, 59), datetime.datetime(2005, 5, 31, 22, 42, 59)),
#  (350, 'GARDEN ISLAND', datetime.datetime(2005, 5, 29, 17, 52, 30), datetime.datetime(2005, 5, 30, 14, 35, 30)),
#  (521, 'LIES TREATMENT', datetime.datetime(2005, 5, 29, 18, 31, 30), datetime.datetime(2005, 5, 31, 0, 18, 30)),
#  (244, 'DORADO NOTTING', datetime.datetime(2005, 5, 29, 20, 0, 30), datetime.datetime(2005, 5, 30, 19, 43, 30)),
#  (42, 'ARTIST COLDBLOODED', datetime.datetime(2005, 5, 29, 20, 39, 14), datetime.datetime(2005, 5, 31, 18, 24, 14)),
#  (715, 'RANGE MOONWALKER', datetime.datetime(2005, 5, 29, 21, 39, 37), datetime.datetime(2005, 5, 30, 22, 6, 37)),
#  (771, 'SCORPION APOLLO', datetime.datetime(2005, 5, 29, 21, 45, 32), datetime.datetime(2005, 5, 31, 19, 1, 32)),
#  (540, 'LUCKY FLYING', datetime.datetime(2005, 5, 29, 22, 14, 55), datetime.datetime(2005, 5, 30, 17, 22, 55)),
#  (791, 'SHOW LORD', datetime.datetime(2005, 5, 29, 23, 24, 30), datetime.datetime(2005, 5, 30, 22, 0, 30)),
#  (690, 'POND SEATTLE', datetime.datetime(2005, 5, 29, 23, 56, 42), datetime.datetime(2005, 5, 31, 4, 11, 42)),
#  (881, 'TEMPLE ATTRACTION', datetime.datetime(2005, 5, 30, 0, 28, 41), datetime.datetime(2005, 5, 31, 20, 39, 41)),
#  (479, 'JEDI BENEATH', datetime.datetime(2005, 5, 30, 0, 44, 24), datetime.datetime(2005, 5, 31, 0, 58, 24)),
#  (521, 'LIES TREATMENT', datetime.datetime(2005, 5, 30, 1, 35, 12), datetime.datetime(2005, 5, 31, 1, 51, 12)),
#  (788, 'SHIP WONDERLAND', datetime.datetime(2005, 5, 30, 4, 19, 55), datetime.datetime(2005, 5, 31, 2, 28, 55)),
#  (889, 'TIES HUNGER', datetime.datetime(2005, 5, 30, 6, 41, 32), datetime.datetime(2005, 5, 31, 7, 39, 32)),
#  (286, 'ENOUGH RAGING', datetime.datetime(2005, 5, 30, 7, 14, 53), datetime.datetime(2005, 5, 31, 7, 56, 53)),
#  (703, 'PUNK DIVORCE', datetime.datetime(2005, 5, 30, 10, 58, 33), datetime.datetime(2005, 5, 31, 9, 31, 33)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 30, 11, 25, 1), datetime.datetime(2005, 5, 31, 9, 6, 1)),
#  (178, 'CONNECTION MICROCOSMOS', datetime.datetime(2005, 5, 30, 11, 32, 24), datetime.datetime(2005, 5, 31, 7, 55, 24)),
#  (255, 'DRIVING POLISH', datetime.datetime(2005, 5, 30, 12, 16, 40), datetime.datetime(2005, 5, 31, 16, 20, 40)),
#  (743, 'ROOM ROMAN', datetime.datetime(2005, 5, 30, 12, 53, 1), datetime.datetime(2005, 5, 31, 14, 28, 1)),
#  (158, 'CLONES PINOCCHIO', datetime.datetime(2005, 5, 30, 12, 55, 36), datetime.datetime(2005, 5, 31, 10, 30, 36)),
#  (305, 'FATAL HAUNTED', datetime.datetime(2005, 5, 30, 16, 10, 35), datetime.datetime(2005, 5, 31, 19, 1, 35)),
#  (474, 'JADE BUNCH', datetime.datetime(2005, 5, 30, 16, 34, 2), datetime.datetime(2005, 5, 31, 20, 34, 2)),
#  (899, 'TOWERS HURRICANE', datetime.datetime(2005, 5, 30, 16, 59, 3), datetime.datetime(2005, 5, 31, 11, 58, 3)),
#  (738, 'ROCKETEER MOTHER', datetime.datetime(2005, 5, 30, 19, 0, 14), datetime.datetime(2005, 5, 31, 17, 10, 14)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 30, 19, 0, 37), datetime.datetime(2005, 5, 31, 23, 51, 37)),
#  (23, 'ANACONDA CONFESSIONS', datetime.datetime(2005, 5, 30, 19, 20, 3), datetime.datetime(2005, 5, 31, 18, 17, 3)),
#  (98, 'BRIGHT ENCOUNTERS', datetime.datetime(2005, 5, 30, 19, 23, 48), datetime.datetime(2005, 5, 31, 21, 14, 48)),
#  (450, 'IDOLS SNATCHERS', datetime.datetime(2005, 5, 31, 0, 6, 20), datetime.datetime(2005, 5, 31, 21, 29, 20))]

# %%
# %%sql
# select f.film_id as Film_ID,f.title as Film_Title,r.rental_date as Rental_Date,r.return_date as Return_date
# from film f
# left join inventory i
# on i.film_id=f.film_id
# left join rental r
# on r.inventory_id=i.inventory_id
# where r.rental_date and r.return_date between'2005-04-30' and '2005-06-01';
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 395 rows affected.
# [(80, 'BLANKET BEVERLY', datetime.datetime(2005, 5, 24, 22, 53, 30), datetime.datetime(2005, 5, 26, 22, 4, 30)),
#  (333, 'FREAKY POCUS', datetime.datetime(2005, 5, 24, 22, 54, 33), datetime.datetime(2005, 5, 28, 19, 40, 33)),
#  (613, 'MYSTIC TRUMAN', datetime.datetime(2005, 5, 24, 23, 8, 7), datetime.datetime(2005, 5, 27, 1, 32, 7)),
#  (870, 'SWARM GOLD', datetime.datetime(2005, 5, 24, 23, 11, 53), datetime.datetime(2005, 5, 29, 20, 34, 53)),
#  (510, 'LAWLESS VISION', datetime.datetime(2005, 5, 24, 23, 31, 46), datetime.datetime(2005, 5, 27, 23, 33, 46)),
#  (565, 'MATRIX SNOWMAN', datetime.datetime(2005, 5, 25, 0, 0, 40), datetime.datetime(2005, 5, 28, 0, 22, 40)),
#  (396, 'HANGING DEEP', datetime.datetime(2005, 5, 25, 0, 2, 21), datetime.datetime(2005, 5, 31, 22, 44, 21)),
#  (347, 'GAMES BOWFINGER', datetime.datetime(2005, 5, 25, 0, 19, 27), datetime.datetime(2005, 5, 30, 5, 44, 27)),
#  (499, 'KING EVOLUTION', datetime.datetime(2005, 5, 25, 0, 22, 55), datetime.datetime(2005, 5, 30, 4, 28, 55)),
#  (593, 'MONTEREY LABYRINTH', datetime.datetime(2005, 5, 25, 0, 31, 15), datetime.datetime(2005, 5, 26, 2, 56, 15)),
#  (86, 'BOOGIE AMELIE', datetime.datetime(2005, 5, 25, 0, 43, 11), datetime.datetime(2005, 5, 26, 4, 42, 11)),
#  (181, 'CONTACT ANONYMOUS', datetime.datetime(2005, 5, 25, 1, 6, 36), datetime.datetime(2005, 5, 27, 0, 43, 36)),
#  (741, 'ROMAN PUNK', datetime.datetime(2005, 5, 25, 1, 10, 47), datetime.datetime(2005, 5, 31, 6, 35, 47)),
#  (422, 'HOLLOW JEOPARDY', datetime.datetime(2005, 5, 25, 1, 17, 24), datetime.datetime(2005, 5, 31, 6, 0, 24)),
#  (770, 'SCISSORHANDS SLUMS', datetime.datetime(2005, 5, 25, 1, 48, 41), datetime.datetime(2005, 5, 27, 2, 20, 41)),
#  (31, 'APACHE DIVINE', datetime.datetime(2005, 5, 25, 1, 59, 46), datetime.datetime(2005, 5, 26, 1, 1, 46)),
#  (159, 'CLOSER BANG', datetime.datetime(2005, 5, 25, 2, 19, 23), datetime.datetime(2005, 5, 26, 4, 52, 23)),
#  (971, 'WHALE BIKINI', datetime.datetime(2005, 5, 25, 2, 40, 21), datetime.datetime(2005, 5, 29, 6, 34, 21)),
#  (721, 'REDS POCUS', datetime.datetime(2005, 5, 25, 2, 53, 2), datetime.datetime(2005, 5, 27, 1, 15, 2)),
#  (863, 'SUN CONFESSIONS', datetime.datetime(2005, 5, 25, 3, 21, 20), datetime.datetime(2005, 5, 27, 21, 25, 20)),
#  (953, 'WAIT CIDER', datetime.datetime(2005, 5, 25, 3, 36, 50), datetime.datetime(2005, 5, 31, 0, 34, 50)),
#  (271, 'EASY GLADIATOR', datetime.datetime(2005, 5, 25, 3, 41, 50), datetime.datetime(2005, 5, 30, 1, 13, 50)),
#  (887, 'THIEF PELICAN', datetime.datetime(2005, 5, 25, 3, 42, 37), datetime.datetime(2005, 5, 26, 9, 26, 37)),
#  (132, 'CHAINSAW UPTOWN', datetime.datetime(2005, 5, 25, 3, 47, 12), datetime.datetime(2005, 5, 30, 0, 31, 12)),
#  (819, 'SONG HEDWIG', datetime.datetime(2005, 5, 25, 4, 1, 32), datetime.datetime(2005, 5, 30, 3, 12, 32)),
#  (979, 'WITCHES PANIC', datetime.datetime(2005, 5, 25, 4, 5, 17), datetime.datetime(2005, 5, 30, 7, 15, 17)),
#  (839, 'STALLION SUNDANCE', datetime.datetime(2005, 5, 25, 4, 6, 21), datetime.datetime(2005, 5, 25, 23, 55, 21)),
#  (367, 'GOLDMINE TYCOON', datetime.datetime(2005, 5, 25, 4, 18, 51), datetime.datetime(2005, 5, 27, 3, 58, 51)),
#  (573, 'MICROCOSMOS PARADISE', datetime.datetime(2005, 5, 25, 4, 19, 28), datetime.datetime(2005, 5, 29, 0, 10, 28)),
#  (284, 'ENEMY ODDS', datetime.datetime(2005, 5, 25, 4, 24, 36), datetime.datetime(2005, 5, 27, 7, 2, 36)),
#  (288, 'ESCAPE METROPOLIS', datetime.datetime(2005, 5, 25, 4, 36, 26), datetime.datetime(2005, 5, 29, 0, 31, 26)),
#  (89, 'BORROWERS BEDAZZLED', datetime.datetime(2005, 5, 25, 4, 44, 31), datetime.datetime(2005, 5, 29, 1, 3, 31)),
#  (976, 'WIND PHANTOM', datetime.datetime(2005, 5, 25, 4, 51, 46), datetime.datetime(2005, 5, 31, 3, 14, 46)),
#  (579, 'MINDS TRUMAN', datetime.datetime(2005, 5, 25, 5, 9, 4), datetime.datetime(2005, 5, 27, 23, 12, 4)),
#  (84, 'BOILED DARES', datetime.datetime(2005, 5, 25, 5, 24, 58), datetime.datetime(2005, 5, 31, 2, 47, 58)),
#  (564, 'MASSAGE IMAGE', datetime.datetime(2005, 5, 25, 5, 39, 25), datetime.datetime(2005, 5, 26, 6, 54, 25)),
#  (681, 'PIRATES ROXANNE', datetime.datetime(2005, 5, 25, 5, 53, 23), datetime.datetime(2005, 5, 29, 10, 56, 23)),
#  (478, 'JAWS HARRY', datetime.datetime(2005, 5, 25, 6, 5, 20), datetime.datetime(2005, 5, 30, 3, 4, 20)),
#  (650, 'PACIFIC AMISTAD', datetime.datetime(2005, 5, 25, 6, 39, 35), datetime.datetime(2005, 5, 30, 10, 12, 35)),
#  (432, 'HOPE TOOTSIE', datetime.datetime(2005, 5, 25, 6, 44, 53), datetime.datetime(2005, 5, 28, 11, 28, 53)),
#  (278, 'ELF MURDER', datetime.datetime(2005, 5, 25, 6, 49, 10), datetime.datetime(2005, 5, 26, 6, 42, 10)),
#  (875, 'TALENTED HOMICIDE', datetime.datetime(2005, 5, 25, 6, 51, 29), datetime.datetime(2005, 5, 31, 1, 27, 29)),
#  (277, 'ELEPHANT TROJAN', datetime.datetime(2005, 5, 25, 7, 19, 16), datetime.datetime(2005, 5, 27, 5, 19, 16)),
#  (252, 'DREAM PICKUP', datetime.datetime(2005, 5, 25, 8, 26, 13), datetime.datetime(2005, 5, 30, 10, 57, 13)),
#  (298, 'EYES DRIVING', datetime.datetime(2005, 5, 25, 8, 28, 11), datetime.datetime(2005, 5, 26, 14, 21, 11)),
#  (858, 'SUBMARINE BED', datetime.datetime(2005, 5, 25, 8, 43, 32), datetime.datetime(2005, 5, 29, 6, 42, 32)),
#  (670, 'PELICAN COMFORTS', datetime.datetime(2005, 5, 25, 8, 53, 14), datetime.datetime(2005, 5, 28, 14, 40, 14)),
#  (73, 'BINGO TALENTED', datetime.datetime(2005, 5, 25, 8, 58, 25), datetime.datetime(2005, 5, 30, 14, 14, 25)),
#  (58, 'BEACH HEARTBREAKERS', datetime.datetime(2005, 5, 25, 9, 18, 52), datetime.datetime(2005, 5, 30, 10, 55, 52)),
#  (873, 'SWEETHEARTS SUSPECTS', datetime.datetime(2005, 5, 25, 9, 19, 16), datetime.datetime(2005, 5, 27, 4, 24, 16)),
#  (776, 'SECRET GROUNDHOG', datetime.datetime(2005, 5, 25, 9, 32, 3), datetime.datetime(2005, 5, 29, 14, 21, 3)),
#  (257, 'DRUMLINE CYCLONE', datetime.datetime(2005, 5, 25, 9, 35, 12), datetime.datetime(2005, 5, 29, 4, 16, 12)),
#  (54, 'BANGER PINOCCHIO', datetime.datetime(2005, 5, 25, 9, 41, 1), datetime.datetime(2005, 5, 27, 13, 46, 1)),
#  (878, 'TEEN APOLLO', datetime.datetime(2005, 5, 25, 9, 47, 31), datetime.datetime(2005, 5, 31, 10, 20, 31)),
#  (705, 'PURPLE MOVIE', datetime.datetime(2005, 5, 25, 10, 10, 14), datetime.datetime(2005, 5, 27, 14, 2, 14)),
#  (468, 'INVASION CYCLONE', datetime.datetime(2005, 5, 25, 10, 15, 23), datetime.datetime(2005, 5, 27, 5, 56, 23)),
#  (525, 'LOATHING LEGALLY', datetime.datetime(2005, 5, 25, 10, 26, 39), datetime.datetime(2005, 5, 28, 4, 59, 39)),
#  (489, 'JUGGLER HARDLY', datetime.datetime(2005, 5, 25, 10, 52, 13), datetime.datetime(2005, 5, 28, 5, 52, 13)),
#  (379, 'GREEDY ROOTS', datetime.datetime(2005, 5, 25, 11, 9, 48), datetime.datetime(2005, 5, 26, 12, 23, 48)),
#  (287, 'ENTRAPMENT SATISFACTION', datetime.datetime(2005, 5, 25, 11, 31, 59), datetime.datetime(2005, 5, 26, 16, 53, 59)),
#  (887, 'THIEF PELICAN', datetime.datetime(2005, 5, 25, 11, 35, 18), datetime.datetime(2005, 5, 31, 12, 48, 18)),
#  (543, 'MADIGAN DORADO', datetime.datetime(2005, 5, 25, 12, 12, 7), datetime.datetime(2005, 5, 31, 17, 46, 7)),
#  (103, 'BUCKET BROTHERHOOD', datetime.datetime(2005, 5, 25, 12, 30, 15), datetime.datetime(2005, 5, 27, 15, 40, 15)),
#  (397, 'HANKY OCTOBER', datetime.datetime(2005, 5, 25, 12, 36, 30), datetime.datetime(2005, 5, 29, 18, 33, 30)),
#  (103, 'BUCKET BROTHERHOOD', datetime.datetime(2005, 5, 25, 13, 5, 34), datetime.datetime(2005, 5, 29, 16, 53, 34)),
#  (491, 'JUMPING WRATH', datetime.datetime(2005, 5, 25, 13, 36, 12), datetime.datetime(2005, 5, 30, 14, 53, 12)),
#  (348, 'GANDHI KWAI', datetime.datetime(2005, 5, 25, 13, 52, 43), datetime.datetime(2005, 5, 29, 11, 12, 43)),
#  (480, 'JEEPERS WEDDING', datetime.datetime(2005, 5, 25, 14, 13, 54), datetime.datetime(2005, 5, 29, 9, 32, 54)),
#  (471, 'ISLAND EXORCIST', datetime.datetime(2005, 5, 25, 14, 28, 29), datetime.datetime(2005, 5, 29, 14, 33, 29)),
#  (169, 'COMFORTS RUSH', datetime.datetime(2005, 5, 25, 15, 38, 46), datetime.datetime(2005, 5, 31, 13, 40, 46)),
#  (366, 'GOLDFINGER SENSIBILITY', datetime.datetime(2005, 5, 25, 16, 3, 42), datetime.datetime(2005, 5, 30, 14, 23, 42)),
#  (748, 'RUGRATS SHAKESPEARE', datetime.datetime(2005, 5, 25, 16, 32, 19), datetime.datetime(2005, 5, 30, 10, 47, 19)),
#  (284, 'ENEMY ODDS', datetime.datetime(2005, 5, 25, 16, 34, 24), datetime.datetime(2005, 5, 28, 12, 13, 24)),
#  (651, 'PACKER MADIGAN', datetime.datetime(2005, 5, 25, 16, 48, 24), datetime.datetime(2005, 5, 27, 11, 29, 24)),
#  (117, 'CANDLES GRAPES', datetime.datetime(2005, 5, 25, 16, 50, 20), datetime.datetime(2005, 5, 28, 18, 52, 20)),
#  (134, 'CHAMPION FLATLINERS', datetime.datetime(2005, 5, 25, 17, 17, 4), datetime.datetime(2005, 5, 31, 19, 47, 4)),
#  (82, 'BLOOD ARGONAUTS', datetime.datetime(2005, 5, 25, 17, 22, 10), datetime.datetime(2005, 5, 31, 19, 47, 10)),
#  (932, 'VALLEY PACKER', datetime.datetime(2005, 5, 25, 17, 46, 33), datetime.datetime(2005, 5, 27, 15, 20, 33)),
#  (173, 'CONFESSIONS MAGUIRE', datetime.datetime(2005, 5, 25, 17, 54, 12), datetime.datetime(2005, 5, 30, 12, 3, 12)),
#  (724, 'REMEMBER DIARY', datetime.datetime(2005, 5, 25, 18, 30, 5), datetime.datetime(2005, 5, 30, 19, 40, 5)),
#  (233, 'DISCIPLE MOTHER', datetime.datetime(2005, 5, 25, 18, 40, 20), datetime.datetime(2005, 5, 29, 20, 39, 20)),
#  (814, 'SNATCH SLIPPER', datetime.datetime(2005, 5, 25, 18, 45, 19), datetime.datetime(2005, 5, 28, 17, 18, 19)),
#  (649, 'OZ LIAISONS', datetime.datetime(2005, 5, 25, 19, 7, 40), datetime.datetime(2005, 5, 27, 22, 16, 40)),
#  (164, 'COAST RAINBOW', datetime.datetime(2005, 5, 25, 19, 13, 25), datetime.datetime(2005, 5, 29, 20, 17, 25)),
#  (973, 'WIFE TURN', datetime.datetime(2005, 5, 25, 19, 27, 51), datetime.datetime(2005, 5, 26, 16, 23, 51)),
#  (931, 'VALENTINE VANISHING', datetime.datetime(2005, 5, 25, 19, 30, 46), datetime.datetime(2005, 5, 31, 23, 59, 46)),
#  (191, 'CROOKED FROGMEN', datetime.datetime(2005, 5, 25, 19, 31, 18), datetime.datetime(2005, 5, 31, 15, 0, 18)),
#  (300, 'FALCON VOLUME', datetime.datetime(2005, 5, 25, 19, 37, 2), datetime.datetime(2005, 5, 29, 23, 51, 2)),
#  (234, 'DISTURBING SCARFACE', datetime.datetime(2005, 5, 25, 19, 41, 29), datetime.datetime(2005, 5, 29, 21, 31, 29)),
#  (390, 'GUYS FALCON', datetime.datetime(2005, 5, 25, 20, 26, 42), datetime.datetime(2005, 5, 26, 19, 41, 42)),
#  (48, 'BACKLASH UNDEFEATED', datetime.datetime(2005, 5, 25, 20, 46, 11), datetime.datetime(2005, 5, 30, 0, 47, 11)),
#  (445, 'HYDE DOCTOR', datetime.datetime(2005, 5, 25, 21, 7, 59), datetime.datetime(2005, 5, 28, 18, 51, 59)),
#  (941, 'VIDEOTAPE ARSENIC', datetime.datetime(2005, 5, 25, 21, 19, 53), datetime.datetime(2005, 5, 29, 23, 34, 53)),
#  (869, 'SUSPECTS QUILLS', datetime.datetime(2005, 5, 25, 21, 21, 56), datetime.datetime(2005, 5, 30, 22, 41, 56)),
#  (177, 'CONNECTICUT TRAMP', datetime.datetime(2005, 5, 25, 21, 42, 46), datetime.datetime(2005, 5, 30, 23, 25, 46)),
#  (738, 'ROCKETEER MOTHER', datetime.datetime(2005, 5, 25, 21, 46, 54), datetime.datetime(2005, 5, 31, 21, 2, 54)),
#  (89, 'BORROWERS BEDAZZLED', datetime.datetime(2005, 5, 25, 21, 48, 30), datetime.datetime(2005, 5, 30, 0, 26, 30)),
#  (500, 'KISS GLORY', datetime.datetime(2005, 5, 25, 22, 2, 30), datetime.datetime(2005, 5, 31, 18, 6, 30)),
#  (898, 'TOURIST PELICAN', datetime.datetime(2005, 5, 25, 22, 48, 22), datetime.datetime(2005, 5, 29, 20, 21, 22)),
#  (73, 'BINGO TALENTED', datetime.datetime(2005, 5, 25, 23, 0, 21), datetime.datetime(2005, 5, 29, 17, 12, 21)),
#  (142, 'CHICKEN HELLFIGHTERS', datetime.datetime(2005, 5, 25, 23, 34, 22), datetime.datetime(2005, 5, 27, 1, 10, 22)),
#  (963, 'WATCH TRACY', datetime.datetime(2005, 5, 25, 23, 43, 47), datetime.datetime(2005, 5, 29, 0, 46, 47)),
#  (186, 'CRAFT OUTFIELD', datetime.datetime(2005, 5, 25, 23, 45, 52), datetime.datetime(2005, 5, 27, 21, 41, 52)),
#  (852, 'STRANGELOVE DESIRE', datetime.datetime(2005, 5, 25, 23, 59, 3), datetime.datetime(2005, 5, 31, 2, 56, 3)),
#  (138, 'CHARIOTS CONSPIRACY', datetime.datetime(2005, 5, 26, 0, 17, 50), datetime.datetime(2005, 5, 29, 23, 21, 50)),
#  (646, 'OUTBREAK DIVINE', datetime.datetime(2005, 5, 26, 0, 37, 28), datetime.datetime(2005, 5, 30, 6, 28, 28)),
#  (849, 'STORM HAPPINESS', datetime.datetime(2005, 5, 26, 0, 47, 47), datetime.datetime(2005, 5, 27, 21, 28, 47)),
#  (299, 'FACTORY DRAGON', datetime.datetime(2005, 5, 26, 0, 55, 56), datetime.datetime(2005, 5, 29, 23, 18, 56)),
#  (702, 'PULP BEVERLY', datetime.datetime(2005, 5, 26, 1, 19, 5), datetime.datetime(2005, 5, 27, 23, 43, 5)),
#  (197, 'CRUSADE HONEY', datetime.datetime(2005, 5, 26, 1, 25, 21), datetime.datetime(2005, 5, 26, 21, 17, 21)),
#  (757, 'SAGEBRUSH CLUELESS', datetime.datetime(2005, 5, 26, 1, 34, 28), datetime.datetime(2005, 5, 29, 4, 0, 28)),
#  (646, 'OUTBREAK DIVINE', datetime.datetime(2005, 5, 26, 1, 51, 48), datetime.datetime(2005, 5, 27, 5, 42, 48)),
#  (272, 'EDGE KISSING', datetime.datetime(2005, 5, 26, 2, 2, 5), datetime.datetime(2005, 5, 27, 3, 38, 5)),
#  (239, 'DOGMA FAMILY', datetime.datetime(2005, 5, 26, 2, 26, 49), datetime.datetime(2005, 5, 28, 0, 32, 49)),
#  (850, 'STORY SIDE', datetime.datetime(2005, 5, 26, 2, 49, 11), datetime.datetime(2005, 5, 31, 1, 28, 11)),
#  (190, 'CREEPERS KANE', datetime.datetime(2005, 5, 26, 2, 50, 31), datetime.datetime(2005, 5, 27, 3, 7, 31)),
#  (382, 'GRIT CLOCKWORK', datetime.datetime(2005, 5, 26, 3, 9, 30), datetime.datetime(2005, 5, 27, 1, 37, 30)),
#  (630, 'NOTTING SPEAKEASY', datetime.datetime(2005, 5, 26, 3, 17, 42), datetime.datetime(2005, 5, 29, 4, 11, 42)),
#  (786, 'SHEPHERD MIDSUMMER', datetime.datetime(2005, 5, 26, 3, 42, 10), datetime.datetime(2005, 5, 28, 1, 37, 10)),
#  (862, 'SUMMER SCARFACE', datetime.datetime(2005, 5, 26, 3, 44, 10), datetime.datetime(2005, 5, 28, 7, 13, 10)),
#  (527, 'LOLA AGENT', datetime.datetime(2005, 5, 26, 4, 47, 6), datetime.datetime(2005, 5, 29, 6, 34, 6)),
#  (429, 'HONEY TIES', datetime.datetime(2005, 5, 26, 5, 29, 49), datetime.datetime(2005, 5, 28, 10, 10, 49)),
#  (734, 'ROAD ROXANNE', datetime.datetime(2005, 5, 26, 5, 47, 12), datetime.datetime(2005, 5, 26, 23, 48, 12)),
#  (219, 'DEEP CRUSADE', datetime.datetime(2005, 5, 26, 6, 1, 41), datetime.datetime(2005, 5, 27, 6, 11, 41)),
#  (951, 'VOYAGE LEGALLY', datetime.datetime(2005, 5, 26, 6, 14, 6), datetime.datetime(2005, 5, 28, 5, 33, 6)),
#  (851, 'STRAIGHT HOURS', datetime.datetime(2005, 5, 26, 6, 41, 48), datetime.datetime(2005, 5, 30, 6, 21, 48)),
#  (295, 'EXPENDABLE STALLION', datetime.datetime(2005, 5, 26, 6, 52, 33), datetime.datetime(2005, 5, 30, 4, 8, 33)),
#  (112, 'CALENDAR GUNFIGHT', datetime.datetime(2005, 5, 26, 6, 52, 36), datetime.datetime(2005, 5, 31, 2, 47, 36)),
#  (43, 'ATLANTIS CAUSE', datetime.datetime(2005, 5, 26, 6, 55, 58), datetime.datetime(2005, 5, 27, 10, 54, 58)),
#  (462, 'INSIDER ARIZONA', datetime.datetime(2005, 5, 26, 7, 11, 58), datetime.datetime(2005, 5, 28, 9, 6, 58)),
#  (856, 'STREETCAR INTENTIONS', datetime.datetime(2005, 5, 26, 7, 12, 21), datetime.datetime(2005, 5, 31, 12, 7, 21)),
#  (401, 'HAROLD FRENCH', datetime.datetime(2005, 5, 26, 7, 30, 37), datetime.datetime(2005, 5, 30, 8, 11, 37)),
#  (68, 'BETRAYED REAR', datetime.datetime(2005, 5, 26, 7, 59, 37), datetime.datetime(2005, 5, 29, 9, 43, 37)),
#  (374, 'GRAFFITI LOVE', datetime.datetime(2005, 5, 26, 8, 1, 54), datetime.datetime(2005, 5, 27, 6, 26, 54)),
#  (21, 'AMERICAN CIRCUS', datetime.datetime(2005, 5, 26, 8, 4, 38), datetime.datetime(2005, 5, 27, 9, 32, 38)),
#  (803, 'SLACKER LIAISONS', datetime.datetime(2005, 5, 26, 8, 10, 22), datetime.datetime(2005, 5, 27, 3, 55, 22)),
#  (159, 'CLOSER BANG', datetime.datetime(2005, 5, 26, 8, 14, 1), datetime.datetime(2005, 5, 27, 9, 0, 1)),
#  (391, 'HALF OUTFIELD', datetime.datetime(2005, 5, 26, 8, 14, 15), datetime.datetime(2005, 5, 27, 12, 12, 15)),
#  (872, 'SWEET BROTHERHOOD', datetime.datetime(2005, 5, 26, 8, 33, 10), datetime.datetime(2005, 5, 28, 14, 9, 10)),
#  (167, 'COMA HEAD', datetime.datetime(2005, 5, 26, 8, 34, 41), datetime.datetime(2005, 5, 30, 12, 46, 41)),
#  (329, 'FORREST SONS', datetime.datetime(2005, 5, 26, 8, 44, 8), datetime.datetime(2005, 5, 31, 12, 33, 8)),
#  (319, 'FISH OPUS', datetime.datetime(2005, 5, 26, 8, 48, 49), datetime.datetime(2005, 5, 31, 4, 6, 49)),
#  (149, 'CHRISTMAS MOONSHINE', datetime.datetime(2005, 5, 26, 9, 2, 47), datetime.datetime(2005, 5, 28, 9, 45, 47)),
#  (961, 'WASH HEAVENLY', datetime.datetime(2005, 5, 26, 9, 24, 26), datetime.datetime(2005, 5, 31, 3, 24, 26)),
#  (676, 'PHILADELPHIA WIFE', datetime.datetime(2005, 5, 26, 9, 41, 45), datetime.datetime(2005, 5, 28, 4, 40, 45)),
#  (783, 'SHANE DARKNESS', datetime.datetime(2005, 5, 26, 10, 14, 9), datetime.datetime(2005, 5, 29, 5, 57, 9)),
#  (602, 'MOURNING PURPLE', datetime.datetime(2005, 5, 26, 10, 14, 38), datetime.datetime(2005, 5, 31, 8, 36, 38)),
#  (686, 'PLUTO OLEANDER', datetime.datetime(2005, 5, 26, 10, 15, 23), datetime.datetime(2005, 5, 30, 11, 43, 23)),
#  (911, 'TRIP NEWTON', datetime.datetime(2005, 5, 26, 10, 44, 4), datetime.datetime(2005, 5, 31, 13, 26, 4)),
#  (48, 'BACKLASH UNDEFEATED', datetime.datetime(2005, 5, 26, 10, 51, 46), datetime.datetime(2005, 5, 30, 7, 24, 46)),
#  (251, 'DRAGONFLY STRANGERS', datetime.datetime(2005, 5, 26, 11, 19, 20), datetime.datetime(2005, 5, 31, 11, 56, 20)),
#  (242, 'DOOM DANCING', datetime.datetime(2005, 5, 26, 11, 31, 50), datetime.datetime(2005, 5, 30, 15, 22, 50)),
#  (878, 'TEEN APOLLO', datetime.datetime(2005, 5, 26, 11, 31, 59), datetime.datetime(2005, 5, 27, 7, 27, 59)),
#  (646, 'OUTBREAK DIVINE', datetime.datetime(2005, 5, 26, 11, 38, 5), datetime.datetime(2005, 5, 27, 8, 42, 5)),
#  (156, 'CLERKS ANGELS', datetime.datetime(2005, 5, 26, 11, 43, 44), datetime.datetime(2005, 5, 28, 17, 28, 44)),
#  (280, 'EMPIRE MALKOVICH', datetime.datetime(2005, 5, 26, 11, 53, 49), datetime.datetime(2005, 5, 28, 13, 55, 49)),
#  (54, 'BANGER PINOCCHIO', datetime.datetime(2005, 5, 26, 12, 15, 13), datetime.datetime(2005, 5, 29, 18, 10, 13)),
#  (112, 'CALENDAR GUNFIGHT', datetime.datetime(2005, 5, 26, 12, 30, 22), datetime.datetime(2005, 5, 27, 6, 49, 22)),
#  (970, 'WESTWARD SEABISCUIT', datetime.datetime(2005, 5, 26, 12, 49, 1), datetime.datetime(2005, 5, 28, 11, 43, 1)),
#  (232, 'DIRTY ACE', datetime.datetime(2005, 5, 26, 13, 40, 40), datetime.datetime(2005, 5, 31, 11, 58, 40)),
#  (668, 'PEAK FOREVER', datetime.datetime(2005, 5, 26, 13, 46, 59), datetime.datetime(2005, 5, 27, 9, 58, 59)),
#  (621, 'NETWORK PEAK', datetime.datetime(2005, 5, 26, 13, 57, 7), datetime.datetime(2005, 5, 29, 10, 12, 7)),
#  (892, 'TITANIC BOONDOCK', datetime.datetime(2005, 5, 26, 14, 1, 5), datetime.datetime(2005, 5, 28, 13, 38, 5)),
#  (416, 'HIGHBALL POTTER', datetime.datetime(2005, 5, 26, 14, 7, 58), datetime.datetime(2005, 5, 31, 14, 3, 58)),
#  (530, 'LORD ARIZONA', datetime.datetime(2005, 5, 26, 14, 19, 9), datetime.datetime(2005, 5, 28, 17, 47, 9)),
#  (81, 'BLINDNESS GUN', datetime.datetime(2005, 5, 26, 14, 30, 24), datetime.datetime(2005, 5, 27, 8, 50, 24)),
#  (948, 'VOICE PEACH', datetime.datetime(2005, 5, 26, 14, 35, 40), datetime.datetime(2005, 5, 29, 17, 17, 40)),
#  (650, 'PACIFIC AMISTAD', datetime.datetime(2005, 5, 26, 14, 43, 14), datetime.datetime(2005, 5, 27, 12, 21, 14)),
#  (398, 'HANOVER GALAXY', datetime.datetime(2005, 5, 26, 14, 43, 48), datetime.datetime(2005, 5, 31, 9, 19, 48)),
#  (719, 'RECORDS ZORRO', datetime.datetime(2005, 5, 26, 14, 52, 15), datetime.datetime(2005, 5, 27, 12, 45, 15)),
#  (702, 'PULP BEVERLY', datetime.datetime(2005, 5, 26, 15, 20, 58), datetime.datetime(2005, 5, 31, 15, 58, 58)),
#  (563, 'MASSACRE USUAL', datetime.datetime(2005, 5, 26, 15, 27, 5), datetime.datetime(2005, 5, 29, 16, 25, 5)),
#  (773, 'SEABISCUIT PUNK', datetime.datetime(2005, 5, 26, 15, 28, 14), datetime.datetime(2005, 5, 30, 18, 38, 14)),
#  (96, 'BREAKING HOME', datetime.datetime(2005, 5, 26, 15, 42, 20), datetime.datetime(2005, 5, 31, 13, 21, 20)),
#  (927, 'UPRISING UPTOWN', datetime.datetime(2005, 5, 26, 15, 46, 56), datetime.datetime(2005, 5, 28, 15, 49, 56)),
#  (256, 'DROP WATERFRONT', datetime.datetime(2005, 5, 26, 15, 47, 40), datetime.datetime(2005, 5, 30, 10, 7, 40)),
#  (449, 'IDENTITY LOVER', datetime.datetime(2005, 5, 26, 16, 0, 49), datetime.datetime(2005, 5, 27, 10, 12, 49)),
#  (727, 'RESURRECTION SILVERADO', datetime.datetime(2005, 5, 26, 16, 8, 5), datetime.datetime(2005, 5, 27, 10, 55, 5)),
#  (268, 'EARLY HOME', datetime.datetime(2005, 5, 26, 16, 16, 21), datetime.datetime(2005, 5, 30, 16, 53, 21)),
#  (374, 'GRAFFITI LOVE', datetime.datetime(2005, 5, 26, 16, 19, 8), datetime.datetime(2005, 5, 27, 14, 35, 8)),
#  (767, 'SCALAWAG DUCK', datetime.datetime(2005, 5, 26, 16, 19, 46), datetime.datetime(2005, 5, 27, 15, 59, 46)),
#  (349, 'GANGS PRIDE', datetime.datetime(2005, 5, 26, 16, 29, 36), datetime.datetime(2005, 5, 29, 18, 49, 36)),
#  (308, 'FERRIS MOTHER', datetime.datetime(2005, 5, 26, 17, 32, 11), datetime.datetime(2005, 5, 28, 22, 54, 11)),
#  (413, 'HEDWIG ALTER', datetime.datetime(2005, 5, 26, 18, 36, 58), datetime.datetime(2005, 5, 27, 23, 42, 58)),
#  (269, 'EARRING INSTINCT', datetime.datetime(2005, 5, 26, 18, 49, 35), datetime.datetime(2005, 5, 27, 18, 11, 35)),
#  (772, 'SEA VIRGIN', datetime.datetime(2005, 5, 26, 19, 5, 5), datetime.datetime(2005, 5, 31, 19, 19, 5)),
#  (545, 'MADNESS ATTACKS', datetime.datetime(2005, 5, 26, 19, 41, 40), datetime.datetime(2005, 5, 31, 16, 58, 40)),
#  (534, 'LOUISIANA HARRY', datetime.datetime(2005, 5, 26, 20, 1, 9), datetime.datetime(2005, 5, 28, 15, 9, 9)),
#  (609, 'MUSCLE BRIGHT', datetime.datetime(2005, 5, 26, 20, 8, 33), datetime.datetime(2005, 5, 30, 0, 32, 33)),
#  (603, 'MOVIE SHAKESPEARE', datetime.datetime(2005, 5, 26, 20, 29, 57), datetime.datetime(2005, 5, 28, 17, 20, 57)),
#  (878, 'TEEN APOLLO', datetime.datetime(2005, 5, 26, 20, 33, 20), datetime.datetime(2005, 5, 27, 18, 23, 20)),
#  (349, 'GANGS PRIDE', datetime.datetime(2005, 5, 26, 20, 48, 48), datetime.datetime(2005, 5, 27, 19, 52, 48)),
#  (241, 'DONNIE ALLEY', datetime.datetime(2005, 5, 26, 20, 52, 26), datetime.datetime(2005, 5, 29, 22, 8, 26)),
#  (956, 'WANDA CHAMBER', datetime.datetime(2005, 5, 26, 20, 55, 36), datetime.datetime(2005, 5, 28, 0, 25, 36)),
#  (246, 'DOUBTFIRE LABYRINTH', datetime.datetime(2005, 5, 26, 21, 16, 52), datetime.datetime(2005, 5, 27, 23, 41, 52)),
#  (610, 'MUSIC BOONDOCK', datetime.datetime(2005, 5, 26, 21, 31, 57), datetime.datetime(2005, 5, 28, 19, 37, 57)),
#  (902, 'TRADING PINOCCHIO', datetime.datetime(2005, 5, 26, 22, 56, 19), datetime.datetime(2005, 5, 29, 1, 29, 19)),
#  (625, 'NONE SPIKING', datetime.datetime(2005, 5, 26, 23, 9, 41), datetime.datetime(2005, 5, 28, 22, 49, 41)),
#  (624, 'NIGHTMARE CHILL', datetime.datetime(2005, 5, 26, 23, 12, 55), datetime.datetime(2005, 5, 29, 23, 33, 55)),
#  (838, 'STAGECOACH ARMAGEDDON', datetime.datetime(2005, 5, 26, 23, 22, 55), datetime.datetime(2005, 5, 29, 23, 25, 55)),
#  (664, 'PATRIOT ROMAN', datetime.datetime(2005, 5, 26, 23, 52, 13), datetime.datetime(2005, 5, 30, 18, 55, 13)),
#  (243, 'DOORS PRESIDENT', datetime.datetime(2005, 5, 27, 0, 9, 24), datetime.datetime(2005, 5, 28, 4, 30, 24)),
#  (514, 'LEBOWSKI SOLDIERS', datetime.datetime(2005, 5, 27, 0, 49, 27), datetime.datetime(2005, 5, 30, 3, 12, 27)),
#  (738, 'ROCKETEER MOTHER', datetime.datetime(2005, 5, 27, 1, 0, 4), datetime.datetime(2005, 5, 30, 4, 27, 4)),
#  (551, 'MAIDEN HOME', datetime.datetime(2005, 5, 27, 1, 9, 55), datetime.datetime(2005, 5, 31, 7, 1, 55)),
#  (583, 'MISSION ZOOLANDER', datetime.datetime(2005, 5, 27, 1, 57, 14), datetime.datetime(2005, 5, 31, 4, 19, 14)),
#  (865, 'SUNRISE LEAGUE', datetime.datetime(2005, 5, 27, 3, 3, 7), datetime.datetime(2005, 5, 29, 3, 54, 7)),
#  (393, 'HALLOWEEN NUTS', datetime.datetime(2005, 5, 27, 3, 15, 23), datetime.datetime(2005, 5, 29, 22, 43, 23)),
#  (875, 'TALENTED HOMICIDE', datetime.datetime(2005, 5, 27, 4, 11, 4), datetime.datetime(2005, 5, 29, 1, 28, 4)),
#  (727, 'RESURRECTION SILVERADO', datetime.datetime(2005, 5, 27, 4, 13, 41), datetime.datetime(2005, 5, 28, 8, 34, 41)),
#  (505, 'LABYRINTH LEAGUE', datetime.datetime(2005, 5, 27, 4, 30, 22), datetime.datetime(2005, 5, 29, 10, 13, 22)),
#  (305, 'FATAL HAUNTED', datetime.datetime(2005, 5, 27, 4, 32, 25), datetime.datetime(2005, 5, 31, 9, 50, 25)),
#  (355, 'GHOSTBUSTERS ELF', datetime.datetime(2005, 5, 27, 4, 40, 33), datetime.datetime(2005, 5, 28, 9, 56, 33)),
#  (641, 'ORANGE GRAPES', datetime.datetime(2005, 5, 27, 4, 53, 11), datetime.datetime(2005, 5, 28, 6, 33, 11)),
#  (953, 'WAIT CIDER', datetime.datetime(2005, 5, 27, 5, 48, 19), datetime.datetime(2005, 5, 29, 9, 5, 19)),
#  (628, 'NORTHWEST POLISH', datetime.datetime(2005, 5, 27, 6, 32, 30), datetime.datetime(2005, 5, 30, 6, 24, 30)),
#  (966, 'WEDDING APOLLO', datetime.datetime(2005, 5, 27, 6, 37, 15), datetime.datetime(2005, 5, 30, 7, 4, 15)),
#  (418, 'HOBBIT ALIEN', datetime.datetime(2005, 5, 27, 6, 43, 59), datetime.datetime(2005, 5, 29, 11, 28, 59)),
#  (255, 'DRIVING POLISH', datetime.datetime(2005, 5, 27, 6, 48, 33), datetime.datetime(2005, 5, 29, 3, 55, 33)),
#  (1, 'ACADEMY DINOSAUR', datetime.datetime(2005, 5, 27, 7, 3, 28), datetime.datetime(2005, 5, 31, 8, 1, 28)),
#  (932, 'VALLEY PACKER', datetime.datetime(2005, 5, 27, 7, 14), datetime.datetime(2005, 5, 28, 12, 22)),
#  (182, 'CONTROL ANTHEM', datetime.datetime(2005, 5, 27, 7, 20, 12), datetime.datetime(2005, 5, 31, 10, 44, 12)),
#  (753, 'RUSH GOODFELLAS', datetime.datetime(2005, 5, 27, 7, 37, 2), datetime.datetime(2005, 5, 30, 5, 43, 2)),
#  (484, 'JERK PAYCHECK', datetime.datetime(2005, 5, 27, 9, 23, 22), datetime.datetime(2005, 5, 29, 15, 20, 22)),
#  (603, 'MOVIE SHAKESPEARE', datetime.datetime(2005, 5, 27, 9, 43, 25), datetime.datetime(2005, 5, 31, 12, 0, 25)),
#  (949, 'VOLCANO TEXAS', datetime.datetime(2005, 5, 27, 10, 12), datetime.datetime(2005, 5, 31, 15, 3)),
#  (344, 'FURY MURDER', datetime.datetime(2005, 5, 27, 10, 23, 25), datetime.datetime(2005, 5, 30, 15, 27, 25)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 27, 10, 26, 31), datetime.datetime(2005, 5, 30, 8, 32, 31)),
#  (96, 'BREAKING HOME', datetime.datetime(2005, 5, 27, 10, 37, 27), datetime.datetime(2005, 5, 30, 5, 45, 27)),
#  (30, 'ANYTHING SAVANNAH', datetime.datetime(2005, 5, 27, 11, 18, 25), datetime.datetime(2005, 5, 28, 7, 10, 25)),
#  (164, 'COAST RAINBOW', datetime.datetime(2005, 5, 27, 11, 45, 49), datetime.datetime(2005, 5, 31, 13, 42, 49)),
#  (228, 'DETECTIVE VISION', datetime.datetime(2005, 5, 27, 11, 47, 4), datetime.datetime(2005, 5, 29, 10, 14, 4)),
#  (912, 'TROJAN TOMORROW', datetime.datetime(2005, 5, 27, 12, 29, 2), datetime.datetime(2005, 5, 28, 17, 36, 2)),
#  (120, 'CARIBBEAN LIBERTY', datetime.datetime(2005, 5, 27, 12, 48, 38), datetime.datetime(2005, 5, 29, 15, 27, 38)),
#  (57, 'BASIC EASY', datetime.datetime(2005, 5, 27, 12, 51, 44), datetime.datetime(2005, 5, 31, 8, 34, 44)),
#  (471, 'ISLAND EXORCIST', datetime.datetime(2005, 5, 27, 12, 57, 55), datetime.datetime(2005, 5, 29, 17, 55, 55)),
#  (101, 'BROTHERHOOD BLANKET', datetime.datetime(2005, 5, 27, 13, 17, 18), datetime.datetime(2005, 5, 30, 8, 53, 18)),
#  (868, 'SUPERFLY TRIP', datetime.datetime(2005, 5, 27, 13, 28, 52), datetime.datetime(2005, 5, 29, 11, 47, 52)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 27, 13, 31, 51), datetime.datetime(2005, 5, 30, 16, 58, 51)),
#  (462, 'INSIDER ARIZONA', datetime.datetime(2005, 5, 27, 13, 46, 46), datetime.datetime(2005, 5, 30, 12, 43, 46)),
#  (240, 'DOLLS RAGE', datetime.datetime(2005, 5, 27, 13, 57, 38), datetime.datetime(2005, 5, 31, 18, 23, 38)),
#  (314, 'FIGHT JAWBREAKER', datetime.datetime(2005, 5, 27, 13, 57, 39), datetime.datetime(2005, 5, 28, 11, 57, 39)),
#  (307, 'FELLOWSHIP AUTUMN', datetime.datetime(2005, 5, 27, 14, 17, 23), datetime.datetime(2005, 5, 29, 15, 7, 23)),
#  (228, 'DETECTIVE VISION', datetime.datetime(2005, 5, 27, 14, 48, 20), datetime.datetime(2005, 5, 31, 14, 39, 20)),
#  (809, 'SLIPPER FIDELITY', datetime.datetime(2005, 5, 27, 14, 51, 45), datetime.datetime(2005, 5, 28, 19, 7, 45)),
#  (517, 'LESSON CLEOPATRA', datetime.datetime(2005, 5, 27, 15, 2, 10), datetime.datetime(2005, 5, 29, 10, 34, 10)),
#  (487, 'JINGLE SAGEBRUSH', datetime.datetime(2005, 5, 27, 15, 7, 27), datetime.datetime(2005, 5, 29, 20, 1, 27)),
#  (735, 'ROBBERS JOON', datetime.datetime(2005, 5, 27, 16, 10, 58), datetime.datetime(2005, 5, 31, 17, 24, 58)),
#  (248, 'DOZEN LION', datetime.datetime(2005, 5, 27, 16, 40, 29), datetime.datetime(2005, 5, 29, 16, 20, 29)),
#  (951, 'VOYAGE LEGALLY', datetime.datetime(2005, 5, 27, 16, 40, 40), datetime.datetime(2005, 5, 30, 19, 55, 40)),
#  (941, 'VIDEOTAPE ARSENIC', datetime.datetime(2005, 5, 27, 17, 21, 4), datetime.datetime(2005, 5, 30, 21, 26, 4)),
#  (973, 'WIFE TURN', datetime.datetime(2005, 5, 27, 18, 0, 35), datetime.datetime(2005, 5, 29, 16, 15, 35)),
#  (346, 'GALAXY SWEETHEARTS', datetime.datetime(2005, 5, 27, 18, 11, 5), datetime.datetime(2005, 5, 30, 22, 45, 5)),
#  (319, 'FISH OPUS', datetime.datetime(2005, 5, 27, 18, 12, 13), datetime.datetime(2005, 5, 30, 12, 30, 13)),
#  (382, 'GRIT CLOCKWORK', datetime.datetime(2005, 5, 27, 18, 42, 57), datetime.datetime(2005, 5, 30, 22, 35, 57)),
#  (45, 'ATTRACTION NEWTON', datetime.datetime(2005, 5, 27, 19, 27, 54), datetime.datetime(2005, 5, 29, 1, 7, 54)),
#  (656, 'PAPI NECKLACE', datetime.datetime(2005, 5, 27, 19, 30, 33), datetime.datetime(2005, 5, 30, 20, 53, 33)),
#  (967, 'WEEKEND PERSONAL', datetime.datetime(2005, 5, 27, 19, 31, 16), datetime.datetime(2005, 5, 29, 23, 6, 16)),
#  (767, 'SCALAWAG DUCK', datetime.datetime(2005, 5, 27, 19, 31, 36), datetime.datetime(2005, 5, 30, 15, 46, 36)),
#  (130, 'CELEBRITY HORN', datetime.datetime(2005, 5, 27, 20, 0, 4), datetime.datetime(2005, 5, 29, 22, 47, 4)),
#  (921, 'UNCUT SUICIDES', datetime.datetime(2005, 5, 27, 20, 2, 3), datetime.datetime(2005, 5, 28, 16, 14, 3)),
#  (290, 'EVERYONE CRAFT', datetime.datetime(2005, 5, 27, 20, 42, 44), datetime.datetime(2005, 5, 30, 0, 49, 44)),
#  (388, 'GUNFIGHT MOON', datetime.datetime(2005, 5, 27, 20, 57, 7), datetime.datetime(2005, 5, 29, 15, 52, 7)),
#  (629, 'NOTORIOUS REUNION', datetime.datetime(2005, 5, 27, 21, 32, 42), datetime.datetime(2005, 5, 31, 0, 39, 42)),
#  (295, 'EXPENDABLE STALLION', datetime.datetime(2005, 5, 27, 21, 36, 15), datetime.datetime(2005, 5, 29, 21, 7, 15)),
#  (322, 'FLATLINERS KILLER', datetime.datetime(2005, 5, 27, 22, 11, 56), datetime.datetime(2005, 5, 31, 19, 7, 56)),
#  (554, 'MALKOVICH PET', datetime.datetime(2005, 5, 27, 22, 16, 26), datetime.datetime(2005, 5, 28, 19, 58, 26)),
#  (93, 'BRANNIGAN SUNRISE', datetime.datetime(2005, 5, 27, 22, 38, 20), datetime.datetime(2005, 5, 31, 18, 39, 20)),
#  (15, 'ALIEN CENTER', datetime.datetime(2005, 5, 27, 22, 49, 27), datetime.datetime(2005, 5, 30, 17, 46, 27)),
#  (330, 'FORRESTER COMANCHEROS', datetime.datetime(2005, 5, 27, 23, 0, 25), datetime.datetime(2005, 5, 28, 21, 30, 25)),
#  (684, 'PIZZA JUMANJI', datetime.datetime(2005, 5, 27, 23, 26, 45), datetime.datetime(2005, 5, 29, 21, 16, 45)),
#  (522, 'LIFE TWISTED', datetime.datetime(2005, 5, 27, 23, 40, 52), datetime.datetime(2005, 5, 28, 22, 40, 52)),
#  (396, 'HANGING DEEP', datetime.datetime(2005, 5, 27, 23, 51, 12), datetime.datetime(2005, 5, 28, 20, 26, 12)),
#  (826, 'SPEED SUIT', datetime.datetime(2005, 5, 28, 0, 0, 30), datetime.datetime(2005, 5, 28, 19, 18, 30)),
#  (422, 'HOLLOW JEOPARDY', datetime.datetime(2005, 5, 28, 0, 9, 12), datetime.datetime(2005, 5, 31, 4, 44, 12)),
#  (771, 'SCORPION APOLLO', datetime.datetime(2005, 5, 28, 0, 9, 56), datetime.datetime(2005, 5, 30, 22, 32, 56)),
#  (293, 'EXORCIST STING', datetime.datetime(2005, 5, 28, 0, 13, 35), datetime.datetime(2005, 5, 29, 0, 11, 35)),
#  (435, 'HOTEL HAPPINESS', datetime.datetime(2005, 5, 28, 0, 24, 58), datetime.datetime(2005, 5, 28, 22, 34, 58)),
#  (40, 'ARMY FLINTSTONES', datetime.datetime(2005, 5, 28, 0, 34, 11), datetime.datetime(2005, 5, 30, 18, 40, 11)),
#  (226, 'DESTINY SATURDAY', datetime.datetime(2005, 5, 28, 0, 40, 48), datetime.datetime(2005, 5, 29, 6, 7, 48)),
#  (101, 'BROTHERHOOD BLANKET', datetime.datetime(2005, 5, 28, 1, 1, 21), datetime.datetime(2005, 5, 30, 21, 20, 21)),
#  (982, 'WOMEN DORADO', datetime.datetime(2005, 5, 28, 1, 5, 25), datetime.datetime(2005, 5, 31, 20, 4, 25)),
#  (131, 'CENTER DINOSAUR', datetime.datetime(2005, 5, 28, 1, 9, 36), datetime.datetime(2005, 5, 30, 6, 14, 36)),
#  (688, 'POLISH BROOKLYN', datetime.datetime(2005, 5, 28, 1, 34, 43), datetime.datetime(2005, 5, 31, 1, 2, 43)),
#  (659, 'PARK CITIZEN', datetime.datetime(2005, 5, 28, 1, 35, 25), datetime.datetime(2005, 5, 28, 22, 12, 25)),
#  (452, 'ILLUSION AMELIE', datetime.datetime(2005, 5, 28, 2, 5, 34), datetime.datetime(2005, 5, 30, 23, 3, 34)),
#  (15, 'ALIEN CENTER', datetime.datetime(2005, 5, 28, 2, 6, 37), datetime.datetime(2005, 5, 29, 6, 57, 37)),
#  (748, 'RUGRATS SHAKESPEARE', datetime.datetime(2005, 5, 28, 2, 51, 12), datetime.datetime(2005, 5, 31, 6, 27, 12)),
#  (945, 'VIRGINIAN PLUTO', datetime.datetime(2005, 5, 28, 2, 52, 14), datetime.datetime(2005, 5, 30, 21, 20, 14)),
#  (50, 'BAKED CLEOPATRA', datetime.datetime(2005, 5, 28, 3, 8, 10), datetime.datetime(2005, 5, 29, 7, 22, 10)),
#  (52, 'BALLROOM MOCKINGBIRD', datetime.datetime(2005, 5, 28, 3, 17, 57), datetime.datetime(2005, 5, 29, 6, 33, 57)),
#  (891, 'TIMBERLAND SKY', datetime.datetime(2005, 5, 28, 3, 18, 2), datetime.datetime(2005, 5, 30, 5, 32, 2)),
#  (524, 'LION UNCUT', datetime.datetime(2005, 5, 28, 3, 32, 22), datetime.datetime(2005, 5, 28, 22, 37, 22)),
#  (702, 'PULP BEVERLY', datetime.datetime(2005, 5, 28, 3, 33, 20), datetime.datetime(2005, 5, 31, 4, 23, 20)),
#  (415, 'HIGH ENCINO', datetime.datetime(2005, 5, 28, 3, 53, 26), datetime.datetime(2005, 5, 31, 5, 58, 26)),
#  (428, 'HOMICIDE PEACH', datetime.datetime(2005, 5, 28, 3, 57, 28), datetime.datetime(2005, 5, 31, 5, 20, 28)),
#  (304, 'FARGO GANDHI', datetime.datetime(2005, 5, 28, 4, 27, 37), datetime.datetime(2005, 5, 30, 7, 52, 37)),
#  (575, 'MIDSUMMER GROUNDHOG', datetime.datetime(2005, 5, 28, 4, 34, 17), datetime.datetime(2005, 5, 30, 0, 35, 17)),
#  (247, 'DOWNHILL ENOUGH', datetime.datetime(2005, 5, 28, 5, 23, 38), datetime.datetime(2005, 5, 29, 8, 0, 38)),
#  (915, 'TRUMAN CRAZY', datetime.datetime(2005, 5, 28, 6, 16, 32), datetime.datetime(2005, 5, 31, 2, 48, 32)),
#  (751, 'RUNAWAY TENENBAUMS', datetime.datetime(2005, 5, 28, 6, 26, 16), datetime.datetime(2005, 5, 30, 2, 2, 16)),
#  (425, 'HOLY TADPOLE', datetime.datetime(2005, 5, 28, 8, 23, 16), datetime.datetime(2005, 5, 31, 3, 29, 16)),
#  (961, 'WASH HEAVENLY', datetime.datetime(2005, 5, 28, 8, 31, 14), datetime.datetime(2005, 5, 30, 7, 34, 14)),
#  (651, 'PACKER MADIGAN', datetime.datetime(2005, 5, 28, 9, 12, 9), datetime.datetime(2005, 5, 29, 5, 7, 9)),
#  (483, 'JERICHO MULAN', datetime.datetime(2005, 5, 28, 9, 57, 36), datetime.datetime(2005, 5, 31, 15, 44, 36)),
#  (249, 'DRACULA CRYSTAL', datetime.datetime(2005, 5, 28, 10, 15, 4), datetime.datetime(2005, 5, 30, 8, 32, 4)),
#  (1000, 'ZORRO ARK', datetime.datetime(2005, 5, 28, 11, 33, 46), datetime.datetime(2005, 5, 29, 8, 33, 46)),
#  (200, 'CURTAIN VIDEOTAPE', datetime.datetime(2005, 5, 28, 12, 3), datetime.datetime(2005, 5, 29, 13, 16)),
#  (309, 'FEUD FROGMEN', datetime.datetime(2005, 5, 28, 12, 5, 33), datetime.datetime(2005, 5, 30, 13, 45, 33)),
#  (19, 'AMADEUS HOLY', datetime.datetime(2005, 5, 28, 12, 8, 37), datetime.datetime(2005, 5, 29, 16, 25, 37)),
#  (83, 'BLUES INSTINCT', datetime.datetime(2005, 5, 28, 13, 11, 4), datetime.datetime(2005, 5, 29, 17, 20, 4)),
#  (139, 'CHASING FIGHT', datetime.datetime(2005, 5, 28, 13, 21, 8), datetime.datetime(2005, 5, 29, 16, 55, 8)),
#  (393, 'HALLOWEEN NUTS', datetime.datetime(2005, 5, 28, 13, 33, 23), datetime.datetime(2005, 5, 30, 17, 10, 23)),
#  (608, 'MURDER ANTITRUST', datetime.datetime(2005, 5, 28, 13, 41, 56), datetime.datetime(2005, 5, 30, 12, 0, 56)),
#  (179, 'CONQUERER NUTS', datetime.datetime(2005, 5, 28, 14, 0, 3), datetime.datetime(2005, 5, 29, 17, 10, 3)),
#  (715, 'RANGE MOONWALKER', datetime.datetime(2005, 5, 28, 14, 27, 51), datetime.datetime(2005, 5, 29, 13, 13, 51)),
#  (561, 'MASK PEACH', datetime.datetime(2005, 5, 28, 15, 2, 41), datetime.datetime(2005, 5, 30, 12, 54, 41)),
#  (273, 'EFFECT GLADIATOR', datetime.datetime(2005, 5, 28, 15, 18, 18), datetime.datetime(2005, 5, 31, 20, 15, 18)),
#  (471, 'ISLAND EXORCIST', datetime.datetime(2005, 5, 28, 15, 24, 54), datetime.datetime(2005, 5, 30, 14, 22, 54)),
#  (900, 'TOWN ARK', datetime.datetime(2005, 5, 28, 15, 49, 14), datetime.datetime(2005, 5, 31, 14, 29, 14)),
#  (253, 'DRIFTER COMMANDMENTS', datetime.datetime(2005, 5, 28, 15, 58, 12), datetime.datetime(2005, 5, 30, 21, 54, 12)),
#  (271, 'EASY GLADIATOR', datetime.datetime(2005, 5, 28, 16, 1, 28), datetime.datetime(2005, 5, 30, 11, 19, 28)),
#  (347, 'GAMES BOWFINGER', datetime.datetime(2005, 5, 28, 18, 14, 29), datetime.datetime(2005, 5, 29, 23, 48, 29)),
#  (914, 'TROUBLE DATE', datetime.datetime(2005, 5, 28, 18, 25, 2), datetime.datetime(2005, 5, 29, 18, 22, 2)),
#  (110, 'CABIN FLASH', datetime.datetime(2005, 5, 28, 18, 43, 26), datetime.datetime(2005, 5, 30, 13, 39, 26)),
#  (682, 'PITTSBURGH HUNCHBACK', datetime.datetime(2005, 5, 28, 18, 52, 11), datetime.datetime(2005, 5, 31, 15, 15, 11)),
#  (417, 'HILLS NEIGHBORS', datetime.datetime(2005, 5, 28, 19, 16, 14), datetime.datetime(2005, 5, 31, 16, 50, 14)),
#  (958, 'WARDROBE PHANTOM', datetime.datetime(2005, 5, 28, 19, 45, 40), datetime.datetime(2005, 5, 29, 21, 2, 40)),
#  (162, 'CLUELESS BUCKET', datetime.datetime(2005, 5, 28, 19, 46, 50), datetime.datetime(2005, 5, 30, 16, 29, 50)),
#  (267, 'EAGLES PANKY', datetime.datetime(2005, 5, 28, 20, 8, 47), datetime.datetime(2005, 5, 29, 14, 57, 47)),
#  (502, 'KNOCK WARLOCK', datetime.datetime(2005, 5, 28, 20, 15, 30), datetime.datetime(2005, 5, 30, 22, 2, 30)),
#  (73, 'BINGO TALENTED', datetime.datetime(2005, 5, 28, 20, 16, 20), datetime.datetime(2005, 5, 31, 16, 46, 20)),
#  (624, 'NIGHTMARE CHILL', datetime.datetime(2005, 5, 28, 20, 18, 24), datetime.datetime(2005, 5, 30, 16, 19, 24)),
#  (303, 'FANTASY TROOPERS', datetime.datetime(2005, 5, 28, 20, 27, 53), datetime.datetime(2005, 5, 31, 1, 36, 53)),
#  (309, 'FEUD FROGMEN', datetime.datetime(2005, 5, 28, 20, 53, 31), datetime.datetime(2005, 5, 30, 15, 26, 31)),
#  (227, 'DETAILS PACKER', datetime.datetime(2005, 5, 28, 21, 38, 39), datetime.datetime(2005, 5, 29, 21, 37, 39)),
#  (174, 'CONFIDENTIAL INTERVIEW', datetime.datetime(2005, 5, 28, 21, 49, 2), datetime.datetime(2005, 5, 31, 3, 7, 2)),
#  (772, 'SEA VIRGIN', datetime.datetime(2005, 5, 28, 21, 54, 45), datetime.datetime(2005, 5, 29, 22, 32, 45)),
#  (506, 'LADY STAGE', datetime.datetime(2005, 5, 28, 22, 27, 51), datetime.datetime(2005, 5, 29, 20, 36, 51)),
#  (694, 'PREJUDICE OLEANDER', datetime.datetime(2005, 5, 28, 23, 53, 18), datetime.datetime(2005, 5, 29, 19, 14, 18)),
#  (532, 'LOSER HUSTLER', datetime.datetime(2005, 5, 29, 0, 27, 10), datetime.datetime(2005, 5, 30, 2, 29, 10)),
#  (377, 'GREASE YOUTH', datetime.datetime(2005, 5, 29, 0, 32, 9), datetime.datetime(2005, 5, 31, 23, 53, 9)),
#  (111, 'CADDYSHACK JEDI', datetime.datetime(2005, 5, 29, 2, 18, 54), datetime.datetime(2005, 5, 30, 5, 54, 54)),
#  (560, 'MARS ROMAN', datetime.datetime(2005, 5, 29, 2, 27, 30), datetime.datetime(2005, 5, 30, 1, 52, 30)),
#  (616, 'NATIONAL STORY', datetime.datetime(2005, 5, 29, 2, 48, 52), datetime.datetime(2005, 5, 30, 6, 21, 52)),
#  (179, 'CONQUERER NUTS', datetime.datetime(2005, 5, 29, 3, 18, 19), datetime.datetime(2005, 5, 30, 2, 45, 19)),
#  (688, 'POLISH BROOKLYN', datetime.datetime(2005, 5, 29, 3, 23, 47), datetime.datetime(2005, 5, 31, 21, 27, 47)),
#  (1000, 'ZORRO ARK', datetime.datetime(2005, 5, 29, 3, 49, 3), datetime.datetime(2005, 5, 31, 8, 29, 3)),
#  (912, 'TROJAN TOMORROW', datetime.datetime(2005, 5, 29, 4, 2, 24), datetime.datetime(2005, 5, 30, 3, 9, 24)),
#  (303, 'FANTASY TROOPERS', datetime.datetime(2005, 5, 29, 4, 37, 44), datetime.datetime(2005, 5, 30, 5, 48, 44)),
#  (247, 'DOWNHILL ENOUGH', datetime.datetime(2005, 5, 29, 5, 28, 47), datetime.datetime(2005, 5, 31, 11, 24, 47)),
#  (747, 'ROXANNE REBEL', datetime.datetime(2005, 5, 29, 5, 34, 44), datetime.datetime(2005, 5, 30, 5, 50, 44)),
#  (356, 'GIANT TROOPERS', datetime.datetime(2005, 5, 29, 6, 8, 15), datetime.datetime(2005, 5, 30, 7, 16, 15)),
#  (896, 'TOOTSIE PILOT', datetime.datetime(2005, 5, 29, 7, 25, 16), datetime.datetime(2005, 5, 30, 5, 21, 16)),
#  (555, 'MALLRATS UNITED', datetime.datetime(2005, 5, 29, 7, 32, 51), datetime.datetime(2005, 5, 30, 10, 8, 51)),
#  (253, 'DRIFTER COMMANDMENTS', datetime.datetime(2005, 5, 29, 9, 33, 33), datetime.datetime(2005, 5, 31, 11, 45, 33)),
#  (159, 'CLOSER BANG', datetime.datetime(2005, 5, 29, 9, 41, 40), datetime.datetime(2005, 5, 30, 13, 31, 40)),
#  (439, 'HUNCHBACK IMPOSSIBLE', datetime.datetime(2005, 5, 29, 11, 32, 15), datetime.datetime(2005, 5, 31, 17, 31, 15)),
#  (239, 'DOGMA FAMILY', datetime.datetime(2005, 5, 29, 11, 37, 35), datetime.datetime(2005, 5, 31, 16, 47, 35)),
#  (266, 'DYNAMITE TARZAN', datetime.datetime(2005, 5, 29, 13, 23, 26), datetime.datetime(2005, 5, 30, 7, 53, 26)),
#  (18, 'ALTER VICTORY', datetime.datetime(2005, 5, 29, 14, 23, 58), datetime.datetime(2005, 5, 30, 17, 44, 58)),
#  (8, 'AIRPORT POLLOCK', datetime.datetime(2005, 5, 29, 15, 8, 41), datetime.datetime(2005, 5, 30, 15, 51, 41)),
#  (166, 'COLOR PHILADELPHIA', datetime.datetime(2005, 5, 29, 16, 13, 55), datetime.datetime(2005, 5, 31, 16, 40, 55)),
#  (623, 'NEWTON LABYRINTH', datetime.datetime(2005, 5, 29, 16, 32, 10), datetime.datetime(2005, 5, 31, 18, 1, 10)),
#  (97, 'BRIDE INTRIGUE', datetime.datetime(2005, 5, 29, 17, 28, 12), datetime.datetime(2005, 5, 30, 14, 59, 12)),
#  (172, 'CONEHEADS SMOOCHY', datetime.datetime(2005, 5, 29, 17, 38, 59), datetime.datetime(2005, 5, 31, 22, 42, 59)),
#  (350, 'GARDEN ISLAND', datetime.datetime(2005, 5, 29, 17, 52, 30), datetime.datetime(2005, 5, 30, 14, 35, 30)),
#  (521, 'LIES TREATMENT', datetime.datetime(2005, 5, 29, 18, 31, 30), datetime.datetime(2005, 5, 31, 0, 18, 30)),
#  (244, 'DORADO NOTTING', datetime.datetime(2005, 5, 29, 20, 0, 30), datetime.datetime(2005, 5, 30, 19, 43, 30)),
#  (42, 'ARTIST COLDBLOODED', datetime.datetime(2005, 5, 29, 20, 39, 14), datetime.datetime(2005, 5, 31, 18, 24, 14)),
#  (715, 'RANGE MOONWALKER', datetime.datetime(2005, 5, 29, 21, 39, 37), datetime.datetime(2005, 5, 30, 22, 6, 37)),
#  (771, 'SCORPION APOLLO', datetime.datetime(2005, 5, 29, 21, 45, 32), datetime.datetime(2005, 5, 31, 19, 1, 32)),
#  (540, 'LUCKY FLYING', datetime.datetime(2005, 5, 29, 22, 14, 55), datetime.datetime(2005, 5, 30, 17, 22, 55)),
#  (791, 'SHOW LORD', datetime.datetime(2005, 5, 29, 23, 24, 30), datetime.datetime(2005, 5, 30, 22, 0, 30)),
#  (690, 'POND SEATTLE', datetime.datetime(2005, 5, 29, 23, 56, 42), datetime.datetime(2005, 5, 31, 4, 11, 42)),
#  (881, 'TEMPLE ATTRACTION', datetime.datetime(2005, 5, 30, 0, 28, 41), datetime.datetime(2005, 5, 31, 20, 39, 41)),
#  (479, 'JEDI BENEATH', datetime.datetime(2005, 5, 30, 0, 44, 24), datetime.datetime(2005, 5, 31, 0, 58, 24)),
#  (521, 'LIES TREATMENT', datetime.datetime(2005, 5, 30, 1, 35, 12), datetime.datetime(2005, 5, 31, 1, 51, 12)),
#  (788, 'SHIP WONDERLAND', datetime.datetime(2005, 5, 30, 4, 19, 55), datetime.datetime(2005, 5, 31, 2, 28, 55)),
#  (889, 'TIES HUNGER', datetime.datetime(2005, 5, 30, 6, 41, 32), datetime.datetime(2005, 5, 31, 7, 39, 32)),
#  (286, 'ENOUGH RAGING', datetime.datetime(2005, 5, 30, 7, 14, 53), datetime.datetime(2005, 5, 31, 7, 56, 53)),
#  (703, 'PUNK DIVORCE', datetime.datetime(2005, 5, 30, 10, 58, 33), datetime.datetime(2005, 5, 31, 9, 31, 33)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 30, 11, 25, 1), datetime.datetime(2005, 5, 31, 9, 6, 1)),
#  (178, 'CONNECTION MICROCOSMOS', datetime.datetime(2005, 5, 30, 11, 32, 24), datetime.datetime(2005, 5, 31, 7, 55, 24)),
#  (255, 'DRIVING POLISH', datetime.datetime(2005, 5, 30, 12, 16, 40), datetime.datetime(2005, 5, 31, 16, 20, 40)),
#  (743, 'ROOM ROMAN', datetime.datetime(2005, 5, 30, 12, 53, 1), datetime.datetime(2005, 5, 31, 14, 28, 1)),
#  (158, 'CLONES PINOCCHIO', datetime.datetime(2005, 5, 30, 12, 55, 36), datetime.datetime(2005, 5, 31, 10, 30, 36)),
#  (305, 'FATAL HAUNTED', datetime.datetime(2005, 5, 30, 16, 10, 35), datetime.datetime(2005, 5, 31, 19, 1, 35)),
#  (474, 'JADE BUNCH', datetime.datetime(2005, 5, 30, 16, 34, 2), datetime.datetime(2005, 5, 31, 20, 34, 2)),
#  (899, 'TOWERS HURRICANE', datetime.datetime(2005, 5, 30, 16, 59, 3), datetime.datetime(2005, 5, 31, 11, 58, 3)),
#  (738, 'ROCKETEER MOTHER', datetime.datetime(2005, 5, 30, 19, 0, 14), datetime.datetime(2005, 5, 31, 17, 10, 14)),
#  (285, 'ENGLISH BULWORTH', datetime.datetime(2005, 5, 30, 19, 0, 37), datetime.datetime(2005, 5, 31, 23, 51, 37)),
#  (23, 'ANACONDA CONFESSIONS', datetime.datetime(2005, 5, 30, 19, 20, 3), datetime.datetime(2005, 5, 31, 18, 17, 3)),
#  (98, 'BRIGHT ENCOUNTERS', datetime.datetime(2005, 5, 30, 19, 23, 48), datetime.datetime(2005, 5, 31, 21, 14, 48)),
#  (450, 'IDOLS SNATCHERS', datetime.datetime(2005, 5, 31, 0, 6, 20), datetime.datetime(2005, 5, 31, 21, 29, 20))]

# %% [markdown]
# ## 6. Pull all the films with ‘Comedy’ category.

# %%
# %%sql
# select f.film_id as Film_ID,f.title as Film_Title,c.name as Category
# from film f
# left join film_category fc
# on fc.film_id=f.film_id
# left join category c
# on c.category_id=fc.category_id
# where c.name='Comedy';
# Out:
#  * mysql://root:***@localhost/mavenmovies
# 58 rows affected.
# [(7, 'AIRPLANE SIERRA', 'Comedy'),
#  (28, 'ANTHEM LUKE', 'Comedy'),
#  (99, 'BRINGING HYSTERICAL', 'Comedy'),
#  (119, 'CAPER MOTIONS', 'Comedy'),
#  (127, 'CAT CONEHEADS', 'Comedy'),
#  (159, 'CLOSER BANG', 'Comedy'),
#  (178, 'CONNECTION MICROCOSMOS', 'Comedy'),
#  (182, 'CONTROL ANTHEM', 'Comedy'),
#  (188, 'CRAZY HOME', 'Comedy'),
#  (202, 'DADDY PITTSBURGH', 'Comedy'),
#  (242, 'DOOM DANCING', 'Comedy'),
#  (247, 'DOWNHILL ENOUGH', 'Comedy'),
#  (265, 'DYING MAKER', 'Comedy'),
#  (276, 'ELEMENT FREDDY', 'Comedy'),
#  (308, 'FERRIS MOTHER', 'Comedy'),
#  (317, 'FIREBALL PHILADELPHIA', 'Comedy'),
#  (324, 'FLINTSTONES HAPPINESS', 'Comedy'),
#  (332, 'FRANKENSTEIN STRANGER', 'Comedy'),
#  (335, 'FREEDOM CLEOPATRA', 'Comedy'),
#  (365, 'GOLD RIVER', 'Comedy'),
#  (385, 'GROUNDHOG UNCUT', 'Comedy'),
#  (388, 'GUNFIGHT MOON', 'Comedy'),
#  (404, 'HATE HANDICAP', 'Comedy'),
#  (410, 'HEAVEN FREEDOM', 'Comedy'),
#  (413, 'HEDWIG ALTER', 'Comedy'),
#  (443, 'HURRICANE AFFAIR', 'Comedy'),
#  (444, 'HUSTLER PARTY', 'Comedy'),
#  (478, 'JAWS HARRY', 'Comedy'),
#  (502, 'KNOCK WARLOCK', 'Comedy'),
#  (522, 'LIFE TWISTED', 'Comedy'),
#  (524, 'LION UNCUT', 'Comedy'),
#  (529, 'LONELY ELEPHANT', 'Comedy'),
#  (555, 'MALLRATS UNITED', 'Comedy'),
#  (568, 'MEMENTO ZOOLANDER', 'Comedy'),
#  (604, 'MULAN MOON', 'Comedy'),
#  (613, 'MYSTIC TRUMAN', 'Comedy'),
#  (638, 'OPERATION OPERATION', 'Comedy'),
#  (657, 'PARADISE SABRINA', 'Comedy'),
#  (660, 'PARTY KNOCK', 'Comedy'),
#  (672, 'PERFECT GROOVE', 'Comedy'),
#  (680, 'PINOCCHIO SIMON', 'Comedy'),
#  (704, 'PURE RUNNER', 'Comedy'),
#  (754, 'RUSHMORE MERMAID', 'Comedy'),
#  (756, 'SADDLE ANTITRUST', 'Comedy'),
#  (765, 'SATURN NAME', 'Comedy'),
#  (774, 'SEARCHERS WAIT', 'Comedy'),
#  (814, 'SNATCH SLIPPER', 'Comedy'),
#  (837, 'STAGE WORLD', 'Comedy'),
#  (857, 'STRICTLY SCARFACE', 'Comedy'),
#  (858, 'SUBMARINE BED', 'Comedy'),
#  (871, 'SWEDEN SHINING', 'Comedy'),
#  (905, 'TRAINSPOTTING STRANGERS', 'Comedy'),
#  (906, 'TRAMP OTHERS', 'Comedy'),
#  (932, 'VALLEY PACKER', 'Comedy'),
#  (938, 'VELVET TERMINATOR', 'Comedy'),
#  (939, 'VERTIGO NORTHWEST', 'Comedy'),
#  (978, 'WISDOM WORKER', 'Comedy'),
#  (1000, 'ZORRO ARK', 'Comedy')]
